# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from wiktionaryparser import WiktionaryParser
import numpy as np
from collections import Counter
from math import isnan

# from code_to_langs import wiki_code_to_lang

# %% [markdown]
# ### 1. Etym-db attempt

# %%
data = pd.read_csv('northeuralex_etymologies.tsv', sep='\t')
data['Value'] = data['Value'].str.lower()
data.head(3)

data.count()
# Out:
# Language_ID     10402
# Value           10402
# Source_ID         769
# Source_Value      769
# dtype: int64

# %%
codes_w = pd.read_csv('wiki_codes.csv')

codes = pd.read_csv('languoid.csv')
codes.dropna(subset=['iso639P3code'])
codes = codes[codes['level']=='language']
codes_2 = codes[['name', 'iso639P3code']].set_index('iso639P3code')

codes = codes[['name', 'iso639P3code']].set_index('name')
codes_w = codes_w[['Canonical name', 'Code']].set_index('Canonical name')
codes_match = codes.join(codes_w).dropna()
codes_match = codes_match.reset_index().drop(['index'], axis=1).set_index('Code')['iso639P3code'].to_dict()

# %%
codes_match_2 = codes_2.to_dict('dict').get('name')
codes_match_2['bua'] = 'Buriat'
codes_match_2['hrv'] = 'Croatian Standard'
codes_match_2['sqi'] = 'Albanian'

data['Language'] = data['Language_ID'].map(codes_match_2)
len(data[data['Language'].isna()]['Language_ID'].unique())
# Out:
# 0

# %% [markdown]
# Get data:

# %%
path_values = "split_etymdb/etymdb_values.csv"
path_link = "split_etymdb/etymdb_links_info.csv"

df_values = pd.read_csv(path_values,
                        sep='\t',
                        names=["id", "lang", "field", "lexeme", "meaning"],
                        dtype={"id": int, "lang": str, "field": int, "meaning": str}).set_index("id")

df_link = pd.read_csv(path_link,
                      sep='\t',
                      names=["relation_type", "child", "parent"],
                      dtype={"relation_type": str, "child": int, "parent": int})

df_inher = df_link.loc[df_link['relation_type'].isin(["inh"])]
df_bor = df_link.loc[df_link['relation_type'].isin(["bor"])]
df_cog = df_link.loc[df_link['relation_type'].isin(["cog"])]

df_values['iso_code'] = df_values['lang'].map(codes_match)
df_values['language_name'] = df_values['lang'].map(wiki_code_to_lang)
# df_values = df_values.dropna()
df_values = df_values.reset_index()
df_values.head(5)
# Out:
#       id lang  field      lexeme                 meaning iso_code  \
# 0      1   en      0  dictionary              dictionary      eng
# 1     10  enm      0        free                    free      enm
# 2    100   ru      0         kot                     NaN      rus
# 3   1000   fy      0       diele  to divide, to separate      NaN
# 4  10000   la      0    proprius               ownership      lat
#
#     language_name
# 0         English
# 1  Middle English
# 2         Russian
# 3    West Frisian
# 4           Latin

# %%
df_link['relation_type'].unique()
# Out:
# array(['der', 'inh', 'cog', 'bor', 'der(s)', 'cmpd+bor', 'der(p)'],
#       dtype=object)

# %% [markdown]
# Dictionary of negative indices:

# %%
# indexes = pd.read_csv('split_etymdb/etymdb_links_index.csv', names=range(20), delimiter='\t').set_index(0)
# dict_indexes = indexes.T.to_dict('list')
# for k, v in dict_indexes.items():
#     dict_indexes[k] = [x for x in v if not isnan(x)]

# dict_indexes

# %%
codes_bg = set(df_values['lexeme'].str.lower().unique())
codes_dt = set(data['Value'].unique())

print('Initial: {}, intersection: {}'.format(len(codes_dt), len(codes_dt.intersection(codes_bg))))
# Out:
# Initial: 9855, intersection: 2899

# %%
lg = set(df_values['language_name'].unique())
lg_2 = set(data[data['Value'].isin(codes_bg)]['Language'].unique())

print('Initial: {}, intersection: {}'.format(len(lg_2), len(lg.intersection(lg_2))))
# Out:
# Initial: 64, intersection: 46

# %%
def get_index_wf(lang, lexeme):
#     index =  df_values.query('iso_code == "{}" & lexeme == "{}"'.format (lang, lexeme)).index[0]
    try:
        index =  df_values.query('language_name == "{}" & lexeme == "{}"'.format(lang, lexeme))['id'].values[0]
        indexes = 0
        if not df_inher.query('child == "{}"'.format(index)).empty:
            ch_idx = df_inher.query('child == "{}"'.format(index))['parent'].values[0]
            return df_values.query('id == {}'.format(int(ch_idx)))[['lexeme', 
                                                                        'iso_code', 'language_name']].values.tolist()[0]
        else:
            pass
    except:
        pass

# %%
dd = []

for row in data[data['Value'].isin(codes_bg)].iterrows():
    value = get_index_wf(row[1]['Language'], row[1]['Value'])
    if value is not None: 
        dd.append((row[0], value))

# %%
len(dd)
# Out:
# 1220

# %%
data['Source_Language'] = 0

# %%
data.head(2)
# Out:
#   Language_ID  Value Source_ID Source_Value Language  Source_Language
# 0         abk  ааира       NaN          NaN   Abkhaz                0
# 1         abk   аара       NaN          NaN   Abkhaz                0

# %%
for element in dd:
    if pd.isnull(data.loc[element[0], 'Source_ID']):
#         print(data.loc[element[0], 'Source_ID'])
        data.loc[element[0], 'Source_Value']  = element[1][0]
        data.loc[element[0], 'Source_ID']  = element[1][1]
        data.loc[element[0], 'Source_Language']  = element[1][2]

# %%
data.count()
# Out:
# Language_ID        10402
# Value              10402
# Source_ID            907
# Source_Value        1472
# Language           10402
# Source_Language    10393
# dtype: int64

# %%
data.to_csv('northeuralex_etymologies_upd.tsv', sep='\t')

# %% [markdown]
# ### 2. Parsing

# %%
from wiktionaryparser import WiktionaryParser

# %%
data_n = pd.read_csv('northeuralex_etymologies_upd.tsv', sep='\t')

# %%
parser = WiktionaryParser()

# %%
parser.fetch('ff', 'ukrainian')
# Out:
# []

# %%
for element in 'persian'.split():
    print(element)
# Out:
# persian

# %%
def parce_etym(lexeme, language):
    result = parser.fetch(lexeme, language)
    if result:
        return result[0].get('etymology')
    elif len(language.split()) >= 2:
        for element in language.split():
#             print('{} {}'.format(lexeme, element))
            res =  parce_etym(lexeme, element)
        return res
    else:
        pass

# %%
parce_etym('dd', 'old russian')

# %%
et = []

for index, row in data_n.iterrows():
    if pd.isnull(row['Source_Value']):
        try:
            etym = parce_etym(row['Value'], row['Language'])
        except:
            pass
        if etym:
            et.append((index, etym))

# %% [markdown]
# ### 3. Correcting

# %%
data_n = pd.read_csv('northeuralex_etymologies_upd.tsv', sep='\t')

# %%
data_n = data_n.drop('Unnamed: 0', axis=1)

# %%
etymologies = data_n['Etymology_raw'][data_n['Etymology_raw'].notna()].to_list()

# %%
etymologies
# Out:
# ['Cognate with Abaza адгьы́л (ādg̍ə́l); compare Georgian ადგილი (adgili).\n',
#  'Compare Old Armenian պինչ (pinčʿ).\n',
#  'Cognate with Adyghe лъэ (łă).\n',
#  'From Proto-Circassian *gʷǝ (“heart”).\n',
#  'From Proto-Circassian *ʐə.\n',
#  'From Proto-Circassian zə.\n',
#  'From Proto-Circassian *kʲʼa.\n',
#  'тхьамыкӏ (tḥāməč̣̍) +\u200e -гъу (-ġ°)',
#  'From Proto-Circassian *ɕʷa',
#  'From Proto-Circassian *t͡ʂʰə (“horse”).\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'From the root ء ث ر\u200e (ʾ-ṯ-r).\n',
#  'From the root ح ب ب\u200e (ḥ-b-b).\n',
#  'From the root د و ر\u200e (d-w-r).\n',
#  'From Proto-Semitic *ʾakal- (root ء ك ل\u200e (ʾ-k-l)).\n',
#  'From the root و ق د\u200e (w-q-d).\n',
#  'From root ن ظ ر\u200e (n-ẓ-r)',
#  'From the root ق ط ع\u200e (q-ṭ-ʿ).\n',
#  'From Proto-Semitic *bint-. Has the Semitic feminine suffix *-at added to the root *bin- of اِبْن\u200e (ibn, “son”).\n',
#  'From root ب ي ت\u200e (b-y-t). From Proto-Semitic *bayt-.\n',
#  'Originally a case form of a defective noun تَحْت\u200e (taḥt, “location that is below”); see the usage note. From the root ت ح ت\u200e (t-ḥ-t).\n',
#  'From the root ت ر ك\u200e (t-r-k).\n',
#  'From the root ك ل م\u200e (k-l-m)',
#  'Synchronically from the root ت ل ل\u200e (t-l-l). Ultimately from Proto-Semitic *tall- (“hill”).\n',
#  'Mediopassive of وَقَّفَ\u200e (waqqafa, “to stop (transitive), to bring to a stop”), from the root و ق ف\u200e (w-q-f); compare وَقَفَ\u200e (waqafa, “to stop (intransitive)”).\n',
#  'From the root ج ل س\u200e (j-l-s)',
#  'From the root ج م ل\u200e (j-m-l).\n',
#  'From the root ح و ف\u200e (ḥ-w-f).\n',
#  'From the root ح ب ب\u200e (ḥ-b-b).\n',
#  'From the root ح ض ر\u200e (ḥ-ḍ-r).\n',
#  'From the root ح م ل\u200e (ḥ-m-l).\n',
#  'From the root ح م ي\u200e (ḥ-m-y).\n',
#  'From the root خ ب ز\u200e (ḵ-b-z).\n',
#  'Derived from the active participle of the verb دَرَّ\u200e (darra, “to flow copiously”), from the root د ر ر\u200e (d-r-r).\n',
#  'From the root د ب ب\u200e (d-b-b).\n',
#  'From the root د خ ل\u200e (d-ḵ-l).\n',
#  'From the root د ف ع\u200e (d-f-ʿ).\n',
#  'From the root د ل ل\u200e (d-l-l).\n',
#  'From the root ذ و ب\u200e (ḏ-w-b)',
#  'From the root ذ ه ب\u200e (ḏ-h-b).\n',
#  'From the root ر ب ط\u200e (r-b-ṭ).\n',
#  'From the root ر ع د\u200e (r-ʿ-d).\n',
#  'From the root ر ف ع\u200e (r-f-ʿ).\n',
#  'From the root س و ق\u200e (s-w-q).\n',
#  'From the root س ح ب\u200e (s-ḥ-b).\n',
#  'From the root س م ع\u200e (s-m-ʿ), from Proto-Semitic *šamaʿ-.\n',
#  'From the root س ن ن\u200e (s-n-n).\n',
#  'From the root ش ر ق\u200e (š-r-q).\n',
#  'From the root ش ع ر\u200e (š-ʿ-r).\n',
#  'From the root ص خ ب\u200e (ṣ-ḵ-b).\n',
#  "From the root ص غ ر\u200e (ṣ-ḡ-r), from Proto-Semitic *ṣ-ɣ-r (“to be small, young”). Cognate with Akkadian 𒌉 (TUR, ṣehru), 𒌉𒁕 (BÀN.DA, ṣehru, “small, young”), Aramaic ܙܥܘܪܐ\u200e (zʿūrā, “small”), Ugaritic 𐎕𐎙𐎗 (ṣġr), Hebrew צָעִיר\u200e (tsa'ír).\n",
#  'From the root ص ق ع\u200e (ṣ-q-ʿ).\n',
#  'From the root ص و ت\u200e (ṣ-w-t). The sense “vote” is probably a loan translation from a European language, most likely French voix, but compare also German Stimme and stimmen, Russian голос (golos) and голосовать (golosovatʹ), etc.\n',
#  'From the root ض ر ب\u200e (ḍ-r-b).\n',
#  'From the root ظ ف ر\u200e (ẓ-f-r), inherited from Proto-Semitic *θ̣upr-, *θ̣ipr-.\n',
#  'From the root ظ ه ر\u200e (ẓ-h-r).\n',
#  'From the root ع ل م\u200e (ʿ-l-m).\n',
#  'From the root ع م ل\u200e (ʿ-m-l). The grammatical “government” meaning is a semantic loan from  Medieval Latin vīs. Compare Hebrew עָמָל\u200e (`Amal, “work, deed”)',
#  'From the root غ ر ب\u200e (ḡ-r-b).\n',
#  'From the roots غ ط ي\u200e (ḡ-ṭ-y) and غ ط و\u200e (ḡ-ṭ-w). Cognate with Hebrew עָטָה\u200e (ʿatá).\n',
#  'From the root غ ن ي\u200e (ḡ-n-y), to be free from want, to be rich, to be full; to be full of sound, resonating.\n',
#  "From the root ف ع ل\u200e (f-ʿ-l); cognate with Hebrew פָּעַל\u200e (pa'ál, “to do”).\n",
#  'From the root ف ه م\u200e (f-h-m).\n',
#  "From the root ق و م\u200e (q-w-m). Compare Hebrew קָם\u200e (kam), Ge'ez ቆመ (ḳomä).\n",
#  'From the root ق د ر\u200e (q-d-r).\n',
#  'From the root ق ذ ر\u200e (q-ḏ-r).\n',
#  'From the root ق س م\u200e (q-s-m).\n',
#  'From the root ق ط ع\u200e (q-ṭ-ʿ).\n',
#  'From the root ق ل ب\u200e (q-l-b).\n',
#  'From the root ق و و\u200e (q-w-w).\n',
#  'From the root ك ث ر\u200e (k-ṯ-r). Adverbial accusative of كَثِير\u200e (kaṯīr, “many”).\n',
#  'From the root ك س ر\u200e (k-s-r), related to breaking.\n',
#  'From the root ك ن س\u200e (k-n-s). In Fraenkel’s and Nöldeke’s view the meaning “to sweep” is from  Aramaic כְּנַשׁ\u200e / ܟܢܝ\u200e (knaš, “to gather; to sweep”), denominal via مِكْنَسَة\u200e (miknasa, “broom”). Note Mehri kənūs (“to sweep”).\n',
#  'From the root ل ع ب\u200e (l-ʿ-b).\n',
#  'From the root ل و ح\u200e (l-w-ḥ). Cognate with Hebrew לוּחַ\u200e (lúakh).\n',
#  'From the root خ ل ب\u200e (ḵ-l-b).\n',
#  'From the root م ر ض\u200e (m-r-ḍ).\n',
#  'Derived from the passive participle of اِسْتَنْقَعَ\u200e (istanqaʿa, “to be or become stagnant”), from the root ن ق ع\u200e (n-q-ʿ).\n',
#  'From the root م س ك\u200e (m-s-k).\n',
#  'From the root م ش ط\u200e (m-š-ṭ). Compare Akkadian 𒄑𒂵𒍮 (/mušṭu/, “comb”).\n',
#  "From Proto-Semitic *malk-. Cognate to Hebrew מֶלֶךְ\u200e (mélekh, “king”) and מָלַךְ\u200e (malákh, “to rule”), and Aramaic מַלְכָּא\u200e (malkā, “king”) and מְלַךְ\u200e (m'laḵ, “to rule”).\n",
#  'From the root ن و م\u200e (n-w-m).\n',
#  'From the root ن ظ ر\u200e (n-ẓ-r).\n',
#  'From the root و ص ل\u200e (w-ṣ-l).\n',
#  'From the root و ض ع\u200e (w-ḍ-ʿ)',
#  'From the root و ل د\u200e (w-l-d), from Proto-Semitic *walad-. Cognate with Akkadian 𒅇𒌅 (walādum), Aramaic יְלַד\u200e (yəlaḏ), Classical Syriac ܝܠܕ\u200e (ilaḏ), Hebrew יָלַד\u200e (yālaḏ) and Ugaritic 𐎊𐎍𐎄 (yld).\n',
#  'From Arabic كَرَّة\u200e (karra).\n',
#  'Compare Old Armenian մագիլ (magil).\n',
#  'From Proto-Avaro-Andian *c̣aʔi, from Proto-North Caucasian *c̣ăjɨ̆.\n',
#  'From Proto-Turkic *ïgač.\n',
#  'From Common Turkic *ālda (“to deceive, fool”), a derivation from Common Turkic *āl (“craftiness; lie; strategy; way of doing”) , whence also dialectal Azerbaijani al (“lie, untruth”).\n',
#  'From Proto-Turkic *ạl- (“to take”). Cognate with Old Turkic 𐰞\u200e (al-) Turkish almak, Chuvash ил (il), etc.\n',
#  'From Proto-Turkic *ạt- (“to throw, shoot”). Cognate with Turkish atmak.\n',
#  'From Proto-Turkic *iak- (“to flow”). Cognate with Old Turkic [script needed] (ak-), Turkish akmak, Chuvash юх (juh).\n',
#  'From Proto-Turkic *āń(k). Cognate with Chuvash уйӑх (ujăh) See Turkish ay for more cognates.\n',
#  'From bağ +\u200e -la. Cognate with Turkish bağlamak.\n',
#  'Equivalent to baş (“head”) +\u200e -la. Cognate with Turkish başlamak. Probably from Proto-Turkic, compare Chuvash пуҫла (puśla, “to start”, transitive).\n',
#  'From bataq +\u200e -lıq.\n',
#  'From Proto-Turkic *bat- (“to sink; to fit into, get into”). Cognate with Kazakh бату (batw).\n',
#  'From Proto-Turkic *bạk- (“to look, watch”). Cognate with Turkish bakmak, Crimean Tatar baqmaq, Turkmen bakmak.\n',
#  'From Proto-Turkic *bil- (“to know”)\nCognate with\nOld Turkic 𐰋𐰃𐰠\u200e (bil-, “to know”),\nTurkish bilmek,\nCrimean Tatar bilmek,\nUzbek bilmoq (“to know”).\nCrimean Tatar bilmek,\nKazakh білу (bilw, “to know”),\nTatar белү (belü)',
#  'Morphologically bişmək (“become cooked”) +\u200e -ir (“causative suffix”). Cognate with Turkish pişirmek (“to cook”), Kazakh пісіру (pisirw, “to cook”), Tatar пешерү (peşerü, “to cook, to boil”), Uyghur پىشىرماق\u200e (pishirmaq, “to cook”).\n',
#  'From Proto-Turkic *büt-, whence also bütün (“all, whole”). Cognate with Turkish bitmek, Chuvash пӗт (pĕt) etc.\n',
#  'Ultimately from Sinitic 茶.\n',
#  'From Proto-Turkic *čebir-. Cognate with Chuvash ҫаврӑн (śavrăn).\n',
#  'From Common Turkic *čeŋe. Cognate with Turkish çene, see there for more.\n',
#  'Borrowed from Persian چنگال\u200e (čangâl).\n',
#  'From Proto-Turkic *čẹr (“rotten, foul; to rot; illness; dirt; to be sick, ill; rot; glue; anguish, sorrow”), whence possibly also Azerbaijani çirk (“dirt”). Cognate with Turkish çürümek.\n',
#  'From Old Anatolian Turkish [script needed] (danışmaq), ultimately a derivation of Proto-Turkic *tạnu- (“to know, get to know”) , whence also Azerbaijani tanımaq. Cognate with Karakhanid تَنُشْماقْ\u200e (tanušmāq, “to talk to each other”), Ottoman Turkish طانشمق\u200e (danışmak, “to advice, counsel”).\n',
#  'From Proto-Turkic *dẹri (“skin”). Cognate with Turkmen deri, Turkish deri,\nKazakh терi (teri),\nKarachay-Balkar тери (teri), Kumyk тери (teri), Kyrgyz тери (teri),\nUzbek teri,\nUyghur تېرە\u200e (tëre),\nYakut тирии (tirii), Dolgan тирии, Tatar тире (tire) and\nBashkir тире (tire).\n',
#  'From Proto-Turkic *dil, *dɨl (“tongue; language”). Cognate with Turkish dil.\n',
#  'From Proto-Turkic *tog-. Cognate with Old Turkic [script needed] (tugur-, “to give birth to”), Uzbek tugʻmoq (“to give birth to”), Chuvash ту (tu).\n',
#  'From Proto-Turkic *duj- (“to perceive (by ears or nose), notice”). Cognate with Turkish duymak.\n',
#  'From Proto-Turkic *tüŕ (“even, level”).\n',
#  'From Proto-Turkic *ẹĺit-. Cognate with Turkish işitmek, Kazakh есту (estw), Uzbek eshitmoq.\n',
#  'From Proto-Turkic *ēt-. Cognate with Old Turkic 𐰃𐱅\u200e (et-, “to make”), Turkish etmek.\n',
#  'From Proto-Turkic *eb (“dwelling place, house”). Cognate with Old Turkic 𐰋\u200e (eb), Turkish ev.\n',
#  'From  Proto-Turkic *ẹri-. Cognate with Turkish erimek.\n',
#  'Ultimately from Proto-Turkic *kē(y)t- (“to go (away), to get away”).\n',
#  'From Proto-Turkic *kīr- (“to enter”). Cognate with Old Turkic 𐰚𐰃𐰼\u200e (kir- /kir²/), Turkish girmek, Chuvash кӗр (kĕr) etc.\n',
#  'From gizləmək +\u200e -t.\n',
#  'From gör (“to see”) +\u200e -ün (“[passive suffix]”). Compare Turkish görünmek.\n',
#  'From Proto-Turkic *kȫk (“blue, green”).\n',
#  'From Arabic هَوَاء\u200e (hawāʾ).\n',
#  'From Proto-Turkic *īĺč (“work, deed”).\n',
#  'From Persian کنار\u200e (kenâr).\n',
#  'From Arabic مَسَافَة\u200e (masāfa).\n',
#  'Cognate with Turkish ödemek, etc.\n',
#  'From Proto-Turkic *bōl- (“to become”). See there for cognates.\n',
#  'From Proto-Turkic *ört- (“to cover”), whence also Azerbaijani örpək (“headscarf”).\nCognate with Turkish örtmek (“to cover, shut”), Chuvash витме (vitme, “to cover, protect, close”), etc.\n',
#  'From Proto-Turkic *ol-tur- (“to sit”), causative of *ol-.\n',
#  'From Proto-Turkic *okï-.\n',
#  'Ultimately from Proto-Turkic *oj- (“to play, to jump”), whence also the derivation oyun (“play, game”). Cognate with\nTurkish oynamak,\nTurkmen oýnamak,\nCrimean Tatar oynamaq,\netc.\n',
#  'Ultimately from Proto-Turkic *ȫ- (“to think of, understand, realize”), and its derivations, such as Proto-Turkic *ȫg (“mind, thought, intelligence”), and Proto-Turkic *ȫgre-, its reflexive form. Cognate with Turkish öğretmek (“to teach”) and Turkish öğrenmek (“to learn”). See there for more.\n',
#  'From Proto-Turkic *buŕ-, *boŕ- (“to damage, destroy”).\nCognate with Turkish bozmak, Chuvash пӑс (păs, “break, destroy”), etc.\n',
#  'From Proto-Turkic *kāpuk (“bark; skin; shell”).\n',
#  'From Common Turkic *kač- (“to run away, flee”). Cognate with Turkish kaçmak etc.\n',
#  'Morphologically from qalxmaq (“to rise”) +\u200e -dır, with /x/ in qalxmaq being lost via syncope. Cognate with Turkish kaldırmak.\n',
#  'From Proto-Turkic *kaŕgan, compare Chuvash хуран (huran).\n',
#  'From Proto-Turkic *kïr- (“to break, demolish; small; to scrape, shave”). Compare Azerbaijani qırxmaq (“to shave”) which is probably a derivation from the same root. Cognate with Turkish kırmak etc.\n',
#  'From Proto-Turkic *kï̄ŕ (“girl, woman”). Cognate with Bashkir ҡыҙ (qïð), Crimean Tatar qız, Karakalpak qız, Kazakh қыз (qız), Kyrgyz кыз (kız), Old Turkic [script needed] (kïz), Ottoman Turkish قیز\u200e, Tatar кыз (qız), Turkish kız, Turkmen gyz, Tuvan кыс (kıs), Uyghur قىز\u200e (qiz), Uzbek qiz.\n',
#  'From Proto-Turkic *kol (“upper arm”). Cognate with Turkish kol, Crimean Tatar qol etc.\n',
#  'From qop- (“to break off”) +\u200e -ar',
#  'Form Common Turkic *kōrï-. Cognate with Old Turkic [script needed] (korï-, “to protect”), Uzbek qoʻrimoq (“to protect”).\n',
#  'Likely from Proto-Turkic. Cognates include Turkish korkmak, Kazakh қорқу (qorqw), Uzbek qoʻrqmoq, Chuvash хӑра (hăra).\n',
#  'From Proto-Turkic *ko-. Cognate with Old Turkic [script needed] (kōd-), [script needed] (kōt-, “to put, to set down, to lay, to place”), Turkish koymak, etc.\n',
#  'From Proto-Turkic *kūrt.\n',
#  'From Arabic صَبَاح\u200e (ṣabāḥ).\n',
#  'From Old Anatolian Turkish [script needed] (sakla-, “to guard, protect”), ultimately from Proto-Turkic *sạk (“aware, alert”). Cognate with Turkish saklamak.\n',
#  'Ultimately from Arabic شَيْء\u200e (šayʾ).\n',
#  'From Proto-Turkic *ses. Cognate with Turkish, Crimean Tatar, Gagauz, Turkish ses, Kazakh сес (ses), Chuvash сасӑ (sasă).\n',
#  'From sın- (“to break”) +\u200e -dır (“causative”).\n',
#  'From Proto-Turkic *soŋ (“back, end”). Compare Turkish son below.\n',
#  'A derivation of Proto-Turkic *soŋ (“end”), whence also son. Cognate with Turkish sonra etc.\n',
#  'From Proto-Turkic *sok- (“to pierce, stick into”), which was homonyms to and possibly cognate with Proto-Turkic *sok- (“to hit, beat, crush”). Compare Karakhanid سُقْماق\u200e (suqmāq), Turkish sokmak (“to insert”), etc.\n',
#  'From Proto-Turkic *sogï-k. Cognate with Turkish soğuk, Uzbek sovuq, Bashkir һыуыҡ (hïwïq), Chuvash сивӗ (sivĕ) etc.\n',
#  'From Proto-Turkic. Cognate with Turkish süpürmek, Chuvash шӑпӑр (šăpăr, “broom”).\n',
#  'Ultimately from Proto-Turkic *sǖr-, cognate with Turkish sürmek.\n',
#  'Cognate with Old Turkic [script needed] (sürüg).\n',
#  'From Proto-Turkic *tepö.\n',
#  'From Proto-Turkic *dik- (“vertical; to to plant vertically”).\nCompare Turkish dikmek (“to sew”), Kumyk тикмек (tikmek, “to sew; to build”) Kazakh тігу (tigw).\n',
#  'From Proto-Turkic *tut- (“to grasp”).\nCognate with Old Turkic 𐱃𐰆𐱃\u200e (tut-, “to keep, catch, own”), Turkish tutmak (“to catch, keep”), Bashkir тотоу (totou, “to keep, hold”), Chuvash тытма (tytma, “to keep, hold”), Khakas & Shor тударға (tudarğa, “to keep, hold, catch, seize, rule, hold back”), Kyrgyz тутуу (tutuu, “to catch”), Turkmen tutmak (“to hold, keep, catch, hire, fill”), Tuvan тудар (tudar, “to hold, catch, grab”), Uzbek tutmoq (“to take, hold, catch”), Yakut тут (tut, “to hold, seize, grab, catch”).\n',
#  'From Proto-Turkic *uŕɨ-n, *uŕa-k (“long, far, late”), whence also uzaq (“far, distant”).\n',
#  'Ultimately from Proto-Turkic *bēr- (“to give”). Cognate with Old Turkic [script needed] (ber-, “to give”), Turkish vermek, etc.\n',
#  'Ultimately from Arabic خَبَر\u200e (ḵabar).\n',
#  'From Proto-Turkic *yāg.\n',
#  'Morphologically from yanmaq (“to burn”) +\u200e -dır',
#  'Ultimately from Proto-Turkic *yāĺ (“young, fresh”).\n',
#  'From Common Turkic *yāša-, a derivation from Proto-Turkic *yāĺ.\n',
#  'From Proto-Turkic *yāy (“summer”).',
#  'From yellə- +\u200e -n.\n',
#  'From Proto-Turkic *yē-. Cognate with Old Turkic [script needed] (ye-, “to eat”), Turkish yemek, etc.\n',
#  'Ultimately from Proto-Turkic *yẹr. Cognate with Old Turkic 𐰘𐰼\u200e (yer), 𐰘𐰃𐰼\u200e (yir).\n',
#  'From Proto-Turkic *uya. Cognate with Chuvash йӑва (jăva).\n',
#  'From Proto-Turkic *adak (“leg”); however, not a regular Kypchak development thereof (which is аяҡ (ayaq)), but apparently a (now extinct) collateral branch with a peculiar semantic shift.\n',
#  'From Proto-Turkic *āń(k) (“moon, month”).\nCognate with Azerbaijani ay, Turkish, Crimean Tatar ay, Tatar, Kazakh, Kyrgyzай (ay), Southern Altai ай (ay), Uzbek oy, etc.\n',
#  'From Proto-Turkic *ạl- (“to take”).\nCognate with Old Turkic [script needed] (al-, “to take”); Turkish almak, Yakut ыл (ıl, “to take”), Chuvash ил (il, “to take”), etc.\n',
#  'From Proto-Turkic *āŋla- (“to understand”), from Proto-Turkic *āŋ (“intelligence, mind”).\nCognate with Old Uyghur [script needed] (aŋla-, “to understand”); Kyrgyz аңдоо (añdoo, “to understand”), Karachay-Balkar ангыларгъа (añılarğa, “to understand”), Uzbek anglamoq (“to understand”), Uyghur ئاڭلىماق\u200e (anglimaq, “to listen; to understand”), Turkish anlamak (“to understand”), Azerbaijani anlamaq (“to understand”).\n',
#  'From Proto-Turkic *agrɨ-g (“pain, illness”), an action noun of *agrɨ- (“to ache; be ill”).\nCognate with\nKarakhanid اَغْرِغْ\u200e (aɣrïɣ, “pain”),\nOld Uyghur ՚՚q̈ryq (aɣrïɣ, “pain, illness”),\nKazakh ауру (awrw, “illness; ill; to be ill”), Kyrgyz оору (ooru), Southern Altai оору (ooru),\nUzbek ogʻriq (“pain, ilness”),\nUyghur ئاغرىق\u200e (aghriq, “illness”),\nKhakas ағырығ (ağırığ, “illness; ill”),\nTuvan аарыг (aarıg, “illness, pain”),\nYakut ыарыы (ıarıı, “pain, disease”),\nTurkish ağrı (“pain, ache”).\n',
#  'From Proto-Turkic *(i)aĺ-a- (“to eat”), from Proto-Turkic *(i)aĺ (“food, meal”).\nCognate with\nOld Uyghur [script needed] (aša-, “to eat”);\nKumyk ашамакъ (aşamaq, “to eat”);\nKarachay-Balkar ашаргъа (aşarğa, “to eat”);\nYakut аһаа (ahaa, “to eat”), etc.\n',
#  'From Common Kypchak *ayaq, from Proto-Turkic *adak (“foot, leg”).\nCompare Old Turkic 𐰑𐰴\u200e (adaq, “leg, foot”).\nSee also аҙаҡ (aðaq).\n',
#  'From *ayt- (“to say, utter”), from Proto-Turkic *ayɨt- (“to say; ask”), which (as seen in Old Uyghur, Yakut, Chuvash cognates) was originally a causative form of an earlier *ay- (“to say”).\nCompare to\nTatar әйтү (äytü, “to say”),\nKazakh айту (aytw, “to say”),\nKyrgyz айтуу (aytuu, “to say”),\nCrimean Tatar aytmaq (“to say”),\nUzbek aytmoq (“to say”),\nUyghur ئېيتماق\u200e (ëytmaq, “to say”),\nKumyk айтмакъ (aytmaq, “to say”),\ndialectal Khakas айт- (ayt-, “to say”), айыт- (ayıt-, “to sing”),\nTurkish ayıtmak (“to say”);\nOld Uyghur [script needed] (ajït-, “to have/make/let sb. say”),\nYakut ыйыт- (ıyıt-, “to ask”),\nChuvash ыйт (yjt, “to ask”).\n',
#  'From Proto-Turkic *iāčɨg (“bitter, acid”).\nA palatal parallel development, compare Bashkir асы (asï, “bitter, sour”) from the same archetype.\n',
#  'From Proto-Turkic *bat-gak (“sticky mud, bog”), from *bat- (“to sink, get bogged/stuck in mud”).\nCognate with\nKazakh батпақ (batpaq),\nKyrgyz баткак (batkak),\nShor патқақ (patqaq),\nKarachay-Balkar батхакъ (batxaq, “clay, mud”),\nUzbek botqoq,\nUyghur پاتقاق\u200e (patqaq, “sticky mud, bog”),\nTurkmen batga (“swamp, bog”),\nTurkish batak (“swamp, bog”).\n',
#  'From Common Kypchak *baw, from Common Turkic *bāğ (“rope, binder”), from Proto-Turkic *b(i)ā- (“to bind, fasten”).\nCognate with\nOld Uyghur [script needed] (bağ, “band, binder; bond”);\nKazakh бау (baw, “cord, binder”),\nKyrgyz боо (boo, “cord, binder”),\nSouthern Altai буу (buu, “cord”),\nCrimean Tatar bav (“knot”),\nUzbek bogʻ (“cord; bundle”),\nTurkish bağ (“connection”),\nYakut быа (bıa, “cord, lace”), etc.\n',
#  'From Proto-Turkic *bīr (“one”).\nCognate with\nOld Turkic 𐰋𐰃𐰼\u200e (bir, “one”), Turkish bir (“one, once”).\n',
#  'From Proto-Turkic *bēr- (“to give”).\nCognate with Old Turkic -𐰋𐰃𐰼 (bér-, “to give”);  Turkish vermek, Yakut биэр (bier), Chuvash пар (par, “to give”), etc.\n',
#  'Cognate with\nKarakhanid [script needed] (butaq, “branch, twig”);\nKazakh бұтақ (butaq),\nKyrgyz бутак (butak),\nSouthern Altai будак (budak, “branch, twig”),\nUzbek butoq (“branch, twig”), etc.\n',
#  'From Proto-Turkic *bōl- (“to become”).\n',
#  'From Persian درست\u200e (dorost, “correct”).\n',
#  'From *yebiĺ(č) (“wet”), from Proto-Turkic *yebi- (“to soak, become wet”).\nCognate with Tatar юеш (yuyeş, “wet”), Karaim йувюш / йӱвӱш / йӱвӱс / йивис (“wet”).\n',
#  'From Common Kypchak *egin "grain crop", from *ekin "cultivated land; crops grown on such land"; from  Proto-Turkic *ek- (“to sow”).\nCognate with\nOld Uyghur [script needed] (ekin, “arable land, tilled land”);\nKazakh егін (egin, “grain crops”),\nKyrgyz эгин (egin, “grain crops”),\nUzbek ekin (“farm crop”),\nUyghur ئېكىن\u200e (ëkin, “arable land; farm crop”),\nTurkish ekin (“farm crop”).\n',
#  'The only reliable cognate is Kazakh ену (enw, “to enter, go in”). Thus, this is a very peculiar regional feature shared by only these two languages.\nGenerally thought to derive from Proto-Turkic *ēn- (“to go down”),.\nHowever, no adequate explanation has been presented as to how this peculiar semantic transformation ("go down" > "enter") could have taken place, and why only in these two languages but not elsewhere.\n',
#  'From Proto-Turkic *ēr (“man”).\n',
#  'From  Proto-Turkic *ẹĺit- (“to hear”).\nCognate with Old Turkic 𐱁𐱅\u200e (eşit-, “to hear, listen”);  Kazakh есту (estw, “to hear”), Uzbek eshitmoq (“to hear”), Turkish işitmek (“to hear”), Khakas истерге (isterge, “to hear”),Yakut иһит (ihit, “to hear”), Chuvash илтме (iltme, “to hear”).\n',
#  'From Proto-Turkic *yāĺ (“young”).\n',
#  'From Common Turkic *yāša- (“to live”), a derivation of Proto-Turkic *yāĺ.\nCognate with\nOld Uyghur [script needed] (jaša-, “to live”);\nKazakh жасау (jasaw, “to live”), \nKumyk яшамакъ (yaşamaq, “to live”), \nUzbek yashamoq (“to find”), \nUyghur ياشىماق\u200e (yashimaq, “to live”), \nSouthern Altai јажа- (ǰaža-, “to live (up to a certain age)”),\nKhakas чазирға (çazirğa, “to live (up to a certain age)”), \nTurkmen ýaşamak, Turkish yaşamak (“to live”).\n',
#  'From *ūdïkla- (“to sleep”), from  *ūdïk "sleepy", derived from *ūdï- \'to sleep\', which in turn derives from *ū "sleep".\nCognate with\nKazakh ұйықтау (uyıqtaw), Kumyk юхламакъ (yuxlamaq), Crimean Tatar yuqlamaq, Kyrgyz укта- (ukta-), Southern Altai уйуктаар (uyuktaar), Chulym уқла- (uqla, “to sleep”), Uzbek uxlamoq, Uyghur ئۇخلىماق\u200e (uxlimaq),\nTurkmen uklamak (“to sleep”).\n',
#  'From Proto-Turkic *yɨlān (“snake”).\nCognate with\nOld Turkic [script needed] (jïlan, “snake”);\nKazakh жылан (jılan), Kyrgyz жылан (cılan),\nUzbek ilon,\nUyghur يىلان\u200e (yilan),\nTurkish yılan,\nKhakas, Tuvan чылан (çılan, “snake”), etc.\n',
#  'From *kürek (“shovel, spade”), from Proto-Turkic *küre- (“to shovel, rake up”).\nCognate with\nKazakh күрек (kürek),\nKyrgyz күрөк (kürök),\nKarachay-Balkar кюрек (kürek),\nKumyk кюрек (kürek),\nUzbek kurak,\nSouthern Altai кӱрек (kürek), Shor кӱрек,\nTurkish kürek,\nCrimean Tatar kürek,\nAzerbaijani kürək (“shovel; spade”).\n',
#  'From Common Turkic *kǖč (“force”).\n',
#  'From *küčlüg "strong" (compare Old Turkic 𐰛𐰈𐰲𐰠𐰈𐰏\u200e (küčlüg, “strong, mighty”)), from Common Turkic *kǖč (“force”) + +lüg "affix of possession or quality".\nSynchronously, equivalent to көс (kös) +\u200e -лө (-lö).\nCognate with\nTatar көчле (köçle),\nCrimean Tatar küçlü,\nUzbek kuchli,\nUyghur كۈچلۈك\u200e (küchlük),\nTurkmen güýçli,\nTurkish güçlü (“strong”), etc.\nSee more cognates at көстө (köstö).\n',
#  'From Proto-Turkic *gǖd- (“to wait; to attend; to respect; to herd”).\nCognate with\nOld Uyghur [script needed] (küt-, “to wait; to herd”);\nKazakh күту (kütw, “to wait”),\nKyrgyz күтүү (kütüü, “to wait; to tend to (cattle)”),\nUzbek kutmoq (“to wait; to tend to (guests)”),\nUyghur كۈتمەك\u200e (kütmek, “to wait”),\nYakut күүт- (küüt-, “to wait”) / көһүт- (köhüt-, “to wait”),\nChuvash кӗт- (kĕt-, “to wait; to herd”).\n',
#  'From  Proto-Turkic *gör- (“to see”).\nCognate with Old Turkic 𐰚𐰇𐰼𐰇𐰼\u200e (körür, “seeing”); Kazakh көру (körw, “to see”), Kyrgyz көрүү (körüü, “to see”), Southern Altai кӧрӧр (körör, “to see”), Uzbek koʻrmoq (“to see”), Khakas кӧрерге (kӧrerge, “to see”), Tuvan көөр (köör, “to see”), Azerbaijani görmək (“to see”), Turkish görmek (“to see”),   Yakut көр (kör, “to see”), Chuvash курма (kurma, “to see”).\n',
#  'From Proto-Turkic *kāpuk (“bark; skin; shell”).\nCognate with\nKazakh қабық (qabıq),\nKyrgyz кабык (kabık), Southern Altai кабык (kabïk),\nUzbek qobiq (“skin, shell”),\nTurkish kabuk (“shell”),\nTuvan хавык (xavık, “husk”),\nChuvash хупӑ (hupă, “bark”),\netc.\n',
#  'From *qayda "where, at what place", from Proto-Turkic *ka- (“interrogative particle”). -da is a locative case formant.\nCognate with\nOld Turkic [script needed] (qajda, “where?”),\nTatar кайда (qayda),\nOttoman Turkish قانده\u200e (kanda),\nKazakh қайда (qayda),\nKyrgyz кайда (kayda),\nCrimean Tatar qayda,\nShor қайда,\nKhakas хайда (xayda),\nTuvan кайда (kayda),\netc.\n',
#  'From Proto-Turkic *kadıŕ (“rawhide; belt”).\nCognate with\nOld Turkic [script needed] (qaðïš, “belt”);\nKazakh қайыс (qayıs, “rawhide”);\nKyrgyz кайыш (kayış, “belt”),\nSouthern Altai кайыш (kayïš, “belt”)Uzbek qayish (“belt”),\nKhakas хаас (xaas, “belt”),\nYakut хатыс (xatıs, “leather strap/belt”),\netc.\n',
#  'From *qara- (“to look”), probably borrowed from Middle Mongolian, from Proto-Mongolic *kara- (“to look”).\nCognate with Kazakh қарау (qaraw, “to look”), Kyrgyz кара- (kara-, “to look”), Southern Altai кара- (kara-, “to look”), Uzbek qaramoq (“to look”), \nUyghur قارىماق\u200e (qarimaq, “to look”), Khakas хара- (xara-, “to look”).\n',
#  'from Common Turkic *xātun (“queen”).\nCompare Old Turkic 𐰴𐱃𐰆𐰣\u200e (qatun, “queen”), Karakhanid قاتُونْ\u200e (qātūn, “noble woman”), Turkish kadın (“woman”).\n',
#  'From Proto-Turkic *kol (“upper arm, hand”).\nCognates include\nOld Uyghur qwl (qol, “arm”);\nTatar кул (qul, “arm, hand”),\nKazakh қол (qol, “arm, hand”),\nUzbek qoʻl (“arm, hand”),\nTurkish kol (“upper arm”),\nYakut хол (xol, “upper arm”),\nChuvash хул (hul, “arm; shoulder”).\n',
#  'From Proto-Turkic *kï̄ŕ (“girl”).\nCognate with\nOld Turkic 𐰶𐰃𐰕\u200e (qïz, “girl”);\nKyrgyz кыз (kız),\nShor қыс,\nTurkish kız (“girl”), etc.\n',
#  'Cognate with\nTatar май (may),\nKazakh май (may),\nKyrgyz май (may),\nUyghur ماي\u200e (may, “oil, butter, fat, grease”).\n',
#  'Cognate with Tatar матур (matur, “beatiful”) and Chuvash маттур (mattur, “strong, stout; dextrous; brave; beatiful”).\nUltimately from Proto-Turkic *bagatur (“hero”).\nIrregular nasalization and preservation of a roundness-disharmonic high vowel are sporadically found in inherited vocabulary but could also indicate some sort of reloaning scenario.\nDoublet of батыр (batïr, “hero, brave”).\n',
#  'From Proto-Turkic *büŋüĺ (“corner”).\nCognate with\nSiberian Tatar мөйәш (möyäš, “corner”),\nKarakalpak мүйеш (“corner”),\nKazakh мүйiс (müyis, “corner”),\nKarachay-Balkar мюйюш (müyüş, “corner”).\n',
#  'Cognate with\nKazakh мылтық (mıltıq),\nNogai мылтык (mıltık),\nUzbek miltiq,\nUyghur مىلتىق\u200e (miltiq),\nKyrgyz мылтык (mıltık),\nSouthern Altai мылтык (mïltïk),\nKhakas мылтых (mıltıx, “rifle”), etc.\n',
#  'From Persian اوستا\u200e (ustâ) / استاد\u200e (ostâd). Doublet of остаз (ostaz).\nNote that the first form in Persian may have been reborrowed from a Turkic source.\nCognate with\nTatar оста (osta, “master, craftsman”),\nKazakh ұста (usta, “master; blacksmith”),\nKyrgyz уста (usta, “master; blacksmith”),\nUzbek usta (“master, professional”),\nUyghur ئۇستا\u200e (usta, “master, professional”),\nTurkish usta (“master”).\n',
#  'From Common Kypchak üy ("house, home", see the Kypchak cognates below), from Proto-Turkic *eb (“house”).\nImmediately cognate with Tatar өй (öy), Kazakh үй (üy), Kyrgyz үй (üy), Karachay-Balkar юй (üy), Kumyk уьй (üy), Southern Altai ӱй (üy, “home, house”).\n',
#  'From *čet (“edge, border; a location aside/away from sth.; foreign”).\nCognate with\nKazakh шет (şet, “edge”),\nKyrgyz чет (çet, “edge”),\nUzbek chet (“edge”),\nUyghur چەت\u200e (chet, “edge”),\nShor чет (“border”), etc.\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)\nCognate with\nTatar тавыш (tawış),\nKazakh дауыс (dawıs),\nKarakalpak даўыс (dawıs),\nKarachay-Balkar таууш (tauuş),\nKyrgyz тоош (tooş),\nUzbek tovush,\nUyghur تاۋۇش\u200e (tawush),\nCrimean Tatar davuş,\nKhakas табыс (tabıs, “voice, sound”).\n',
#  'From Proto-Turkic *dil (“tongue; language”).\nCognate with\nTatar тел (tel),\nKazakh тіл (til),\nKyrgyz тил (til),\nUzbek til,\nTurkish dil (“tongue, language”).\n',
#  'From Proto-Turkic *deri (“skin”).\nCognate with\nKazakh терi (teri),\nKarachay-Balkar тери (teri),\nKumyk тери (teri),\nKyrgyz тери (teri),\nUzbek teri,\nUyghur تېرە\u200e (tëre),\nYakut тирии (tirii),\nTurkmen deri,\nAzerbaijani dəri,\nTurkish deri (“skin”).\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)\nNo etymology is known. No cognates are known.\nSee also the diminutive тоҡсай (toqsay).\n',
#  'From Proto-Turkic *tur- (“to stand”).\n',
#  'From  Proto-Turkic *tut- (“to hold; keep; catch”).\nCognate with Old Turkic 𐱃𐰆𐱃\u200e (tut-, “to keep, catch, own”);\nKyrgyz тутуу (tutuu, “to catch”),\nUzbek tutmoq (“to take, hold, catch”),\nUyghur تۇتماق\u200e (tutmaq, “to hold, grab”),\nTurkish tutmaq (“to catch, keep”),\nAzerbaijani tutmaq (“to catch, keep”),\nTurkmen tutmak (“to hold, keep, catch, hire, fill”),\nKhakas & Shor тударға (tudarğa, “to keep, hold, catch, seize, rule, hold back”),\nTuvan тудар (tudar, “to hold, catch, grab”), Yakut тут (tut, “to hold, seize, grab, catch”),\nChuvash тытма (tytma, “to keep, hold”), etc.\n',
#  'From Proto-Turkic *tǖĺ (“dream (seen while sleeping)”).\n',
#  'From a Mongolic source, from Proto-Mongolic *töle- (“to pay”).\nCognate with\nOld Uyghur [script needed] (tölä-, “to pay”);\nKazakh төлеу (tölew), Kyrgyz төлөө (tölöö), Uzbek toʻlamoq, Uyghur تۆلىمەك\u200e\u200e (tölimek\u200e),\nKhakas тӧле- (tӧle-), Tuvan төлээр (töleer, “to pay”).\n',
#  'From *tögerek "round, circle", from\nProto-Turkic *dög ~ *deg ~ *dog (“round, circle”).\nCompare with\nTatar түгәрәк (tügäräq),\nKazakh төңірек (töñirek),\nKyrgyz төгөрөк (tögörök),\nUzbek toʻgarak (“circle”),\nUyghur تۈگۈرەك\u200e (tügürek, “circle”),\nYakut төгүрүк (tögürük, “round”).\nThe noun sense of "hobby group" is semantic loan from  Russian кружо́к (kružók).\n',
#  'From Proto-Turkic *dɨrŋa-k (“fingernail, claw”).\nCognate with\nOld Turkic 𐱃𐰃𐰺𐰭𐰴\u200e (tïrŋaq, “fingernail, claw”);\nKazakh тырнақ (tırnaq),\nKyrgyz тырмак (tırmak),\nUzbek tirnoq,\nUyghur تىرناق\u200e (tirnaq),\nCrimean Tatar tırnaq,\nTurkish tırnak,\nTurkmen dyrnak,\nTuvan дыргак (dırgak),\nYakut тыҥырах (tıŋırax, “fingernail, claw”).\n',
#  'From Proto-Turkic *o-l (“that”). Compare Old Anatolian Turkish 𐰆𐰞\u200e (ol) and Karakhanid اُلْ\u200e (ol).\n',
#  'From Proto-Turkic *oltur- (“sit”).\n',
#  'From Proto-Turkic *sā-n (“number”), from Proto-Turkic *sā- (“to count”).\nCognate with:\nOld Uyghur s՚n (san, “number”).\n',
#  'From Proto-Turkic *sogɨ-k (“cold”).\nCognate with\nOld Turkic [script needed] (soγïq), Old Turkic [script needed] (soγuq, “cold”),\nKazakh суық (swıq), Kyrgyz суук (suuk), Uyghur سوغۇق\u200e (soghuq)/Uyghur соғуқ (soghuq), Uzbek sovuq, Tuvan соок (sook), Turkmen sowuk, Turkish soğuk (“cold”), etc.\n',
#  'From Persian چشمه\u200e (češme, “spring, source”).\n',
#  'From Proto-Turkic *īĺč (“work, deed”). Compare Turkish iş.\n',
#  'From the noun эш.\n',
#  'Probably a derivation of Proto-Turkic *yara- (“be good enough, be sufficient, be successful”), appended with the causative suffix -t.\nCognate with \nTatar ярату (yaratu, “to love”),\nKazakh жарату (jaratw, “to like, approve of”),\nKyrgyz жаратуу (caratuu, “to like, approve of”),\nUyghur ياراتماق\u200e (yaratmaq, “to love, sypathize”).\n',
#  'From Proto-Slavic *(j)edinъ, ultimately from Proto-Indo-European *óynos (“one, single”).\n',
#  'From Proto-Slavic *bojàti.\n',
#  'From Proto-Slavic *ǫgъlъ. Cognate with Russian у́гол (úgol).\n',
#  'From Proto-Slavic *vęzati.\n',
#  'From Proto-Slavic *grǫdь.\n',
#  'Unknown, cognate with Russian гуля́ть (guljátʹ), Ukrainian гуля́ти (huljáty).\n',
#  'From Proto-Slavic *dȍmъ (“house; home”).\n',
#  'A borrowing from Old Church Slavonic дрѣво (drěvo); ultimately from Proto-Slavic *dervo, from Proto-Indo-European *dóru. Doublet of дзе́рава (dzjérava), the inherited East Slavic form.\n',
#  'From Proto-Slavic *žiti (compare Russian жить (žitʹ), Ukrainian жи́ти (žýty), Old Church Slavonic жити (žiti)), from Proto-Indo-European *gʷeih₃w- (“to live”). Cognate to Lithuanian gyventi, Sanskrit जीवति (jīvati), Latin vīvō.\n',
#  'Cognates include Russian звони́ть (zvonítʹ), Ukrainian дзвони́ти (dzvonýty) and Polish dzwonić.\n',
#  'From Old East Slavic коньць (konĭcĭ, “end; edge, border”), from Proto-Slavic *konьcь (“end”).\n',
#  'From ко́лькі (kólʹki) +\u200e -асць (-ascʹ).\n',
#  'From Proto-Slavic *listъ (“leaf”). Cognate with Russian лист (list).\n',
#  'From лік (lik).\n',
#  'From Old East Slavic мѣстьце (městĭce), мѣстце (městce), from Proto-Slavic *městьce, from *město (“place, town”) +\u200e *-ьce. Equivalent to ме́ста (mjésta) +\u200e -ца (-ca).\nCognate with Ukrainian мі́сце (mísce), Polish miejsce.\n',
#  'From Proto-Slavic *měsęcь, from Proto-Indo-European *mḗh₁n̥s.\n',
#  'From Proto-Slavic *noga, from Proto-Indo-European *h₃nogʰ-.\n',
#  'Cognate with Russian подня́ть (podnjátʹ).\n',
#  'Cognate with Russian поки́нуть (pokínutʹ).\n',
#  'From Old East Slavic пальць (palĭcĭ), from Proto-Slavic *palьcь (“thumb, finger”).\n',
#  'па- (pa-) +\u200e чуць (čucʹ)',
#  'Cognate with Russian по́лдень (póldenʹ).\n',
#  'From Polish skóra, from Proto-Slavic *skora. Cognate with Russian скора́ (skorá). Doublet of шку́ра (škúra) and скі́ра (skíra).\n',
#  'From Proto-Slavic *sъ̀nъ, from Proto-Indo-European *supnós.\n',
#  'From Proto-Slavic *starъ.\n',
#  'From Proto-Slavic *tьnъkъ. Cognate with Russian то́нкий (tónkij).\n',
#  'From у- (u-) +\u200e стаць (stacʹ). Cognates include Ukrainian уста́ти (ustáty), Russian встать (vstatʹ) and Polish wstać.\n',
#  'From Proto-Slavic *tęgnǫti. Cognate with Ukrainian тягну́ти (tjahnúty).\n',
#  'From Proto-Slavic *čakati, *čekati.\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.). Cognate with Ukrainian шту́рхати (štúrxaty).\n',
#  'Borrowed from Sanskrit अग्नि (agni), from Proto-Indo-Aryan *agní, from Proto-Indo-Iranian *Hagnis, from Proto-Indo-European *h₁n̥gʷnis',
#  'Locative of এখান (ekhan)',
#  'Locative of ওখান (okhan)',
#  'Borrowed from Sanskrit खाद्य (khādya).\n',
#  'Akin to Hindi खेलना (khelnā)',
#  'From Sanskrit গল (gala). Cognate to Hindi गला (galā).',
#  'Compare to Hindustani देखना (dekhnā) / دیکھنا\u200e (dekhnā)',
#  'Compare to Hindustani पढ़ना (paṛhnā) / پڑھنا\u200e (paṛhnā).\n',
#  'Compare to Assamese বোলা (büla), Hindi बोलना (bolnā), Marathi बोलणें (bolṇẽ) and Punjabi ਬੋਲਣਾ (bolṇā).\n',
#  'Cognate with Assamese শুনা (xuna)',
#  'From Proto-Celtic *amstera (“time, moment”). Cognate with Welsh amser, Irish aimsir.\n',
#  'Borrowed from Latin discō (“I learn”). Cognate with Welsh dysgu and Cornish dyski, from the same origin.\n',
#  "Infinitive from kavout (to find), all other forms from the verb bezañ (to be). Cognate with Cornish kavos and y'm beus.\n",
#  'Verbal noun from Old Breton oper, from Latin opera (cf. Cornish ober, Welsh gober). Inflected forms in gr- from an earlier gwr-, itself from Proto-Celtic *wregeti, cognate with Welsh gwneud (older forms with initial gwr-) and Cornish gwul (all forms in gwr-).\n',
#  'Borrowed from Latin saccus. Cognate with Welsh sach.\n',
#  'From Proto-Brythonic *ti, from Proto-Celtic *tū, from Proto-Indo-European *túh₂. Cognate to Welsh ti.\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'From Proto-Slavic *biti.\n',
#  'From Proto-Slavic *bordà, from Proto-Indo-European *bʰardʰéh₂.\n',
#  'From Proto-Slavic *bergъ.\n',
#  'From Proto-Slavic *běgati (“to flee, run”).\n',
#  'From Proto-Slavic *vorta\xa0n\xa0pl, reanalyzed as a feminine singular.\n',
#  'From Proto-Slavic *vermę.\n',
#  'Cognate with Slovene vrv, Serbo-Croatian врвца/vrvca and врпца/vrpca, Russian верёвка (verjóvka).\n',
#  'връ́з(вам) (vrǎ́z(vam)) +\u200e -ка (-ka)',
#  'From Proto-Slavic *vьrxъ.\n',
#  'From Proto-Slavic *vьlna (“wool”), from Proto-Indo-European *h₂wĺ̥h₁neh₂ (“wool”).\n',
#  'From Proto-Slavic *govoriti, from Proto-Indo-European *gow(H)- (“to call, cry”).\n',
#  'Diminutive of ду́па (dúpa, “gap, indention”) (mostly obsolete) +\u200e -ка (-ka).\n',
#  'From Proto-Slavic *drъvo, from Proto-Indo-European *dóru.\n',
#  'From Proto-Slavic *(j)ęzykъ, from Proto-Indo-European *dn̥ǵʰwéh₂s.\n',
#  'Deverbial noun from жела́я (želája, “to wish, to desire”) +\u200e -ние (-nie), from Proto-Slavic *želati.\n',
#  'From Proto-Slavic *živěti.\n',
#  'From Proto-Slavic *zemľa, from Proto-Balto-Slavic *źemē, from Proto-Indo-European *dʰéǵʰōm.\n',
#  'From Proto-Slavic *jьti.\n',
#  'From Proto-Slavic *kalъ.\n',
#  'From Proto-Slavic *klonъ.\n',
#  'From Proto-Slavic *koža.\n',
#  'From Proto-Slavic *kora, from Proto-Indo-European *ker-.\n',
#  'From Proto-Slavic *krajь.\n',
#  'From Proto-Slavic *korkъ (“limb, span”).\n',
#  'From Proto-Slavic *kǫsъ. Cognate with Russian кус (kus) and кусок (kusok), Slovene kos, Serbo-Croatian кус, kus, Slovak kus. Non-Slavic cognates include Sanskrit खादति (khādati, “he chews”), Persian خاییدن\u200e (xāyīdan, “to chew”).\n',
#  'From Proto-Slavic *lopata. Morphologically formed from лоп- (lop-, “sheet, spade”) +\u200e -ата (-ata).\n',
#  'From Proto-Slavic *lošь.\n',
#  'From Proto-Slavic *měsęcь, from Proto-Indo-European *mḗh₁n̥s.\n',
#  'Inherited from Proto-Slavic *moťь.\n',
#  'From Proto-Slavic *město.\n',
#  'From Proto-Slavic *noga (originally: claw), from Proto-Indo-European *h₃nogʰ-.\n',
#  'From Proto-Slavic *nogъtь, ultimately from Proto-Indo-European *h₃nogʰ-.\n',
#  'Formed as об- (ob-) +\u200e върна (vǎrna, “to return”).\n',
#  'о- (o-) +\u200e пи́там (pítam)',
#  'From Proto-Slavic *paziti.\n',
#  'From Proto-Slavic *podъ.\n',
#  'From Proto-Slavic *prǫtъ.\n',
#  'From Proto-Slavic *orbota, from *orbъ (“slave”) + *-ota.\n',
#  'Deverbial noun from разстоя́ (razstojá, “to be at a distance”) +\u200e -ние (-nie), from Proto-Slavic *orzstojati.\n',
#  'From Proto-Slavic *rǫka, from Proto-Balto-Slavic *ránkāˀ.\n',
#  'с- (s-) +\u200e въ́рша (vǎ́rša)',
#  'From Proto-Slavic *sila.\n',
#  'From Proto-Slavic *silьnъ.\n',
#  'From Proto-Slavic *synъ, from Proto-Balto-Slavic *sū́ˀnus, from Proto-Indo-European *suHnús.\n',
#  'с- (s-) +\u200e кри́я (kríja)',
#  'From Old Church Slavonic стати (stati), from Proto-Slavic *stati (“to stand, become”).\n',
#  'From Proto-Slavic *starъ.\n',
#  'From Proto-Slavic *stornà (“side, land”); morphologically from стор (stor, “spread, extension”) (obsolete, archaic) +\u200e -на (-na).\n',
#  'From Proto-Slavic *sъ̀nъ, from Proto-Indo-European *supnós.\n',
#  'From Proto-Slavic *tvьrdъ.\n',
#  'From Proto-Slavic *tъgъda (“then”) + -ва (-va).\n',
#  'From Proto-Slavic *tьnъkъ. Akin to English thin, tight.\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'Probably of Iranian origin (compare Persian خوب\u200e (“good”)), formally from Proto-Slavic *xubъ + -ав (-av). Cognate with Macedonian убав (ubav).\n',
#  'From Proto-Slavic *čьrta.\n',
#  'From Proto-Slavic *ǫgъlъ, from Proto-Indo-European *h₂engulos (“joint?”), from *h₂eng- (“corner”).\n',
#  'Uncertain. Possibly of pre-Roman origin, or of Gothic origin. Compare Spanish amagar (“to threaten”) and  Portuguese esmagar.\n',
#  'Borrowed from French attraper.',
#  'From Old Occitan, from Medieval Latin, Late Latin bursa, from Ancient Greek βύρσα (búrsa). Doublet of borsa.\n',
#  'From camí +\u200e -ar.\n',
#  'From Latin corrigia, attested from 1271.',
#  'Possibly from Latin de ex pressum, or more likely from Old Catalan despuix, despuis, depuis (itself from Latin de post) + aprés.',
#  'From Old Occitan [Term?] (compare Occitan ensenhar), from Vulgar Latin insignāre, present active infinitive of insignō (compare French enseigner, Spanish enseñar), from Latin signō.\n',
#  'From Old Occitan, from Medieval Latin friscus, frescus, of Germanic origin, from Proto-Germanic *friskaz. More at English fresh.\n',
#  'From Italian pantano, attested from the 14th century.',
#  'From Old Occitan [Term?], from Vulgar Latin *passāre, from Latin passum, supine of pando (“I stretch, I spread out”). Compare Occitan passar, French passer, Spanish pasar, Italian passare.\n',
#  'From Old Occitan, from Vulgar Latin *pendicāre, from Latin pendēre, present active infinitive of pendeō, from Proto-Italic *pendēō, from Proto-Indo-European *(s)pend- (“to pull; to spin”)',
#  'From Old Occitan, from Vulgar Latin *pīccāre, itself a derivative of Latin pīcus or of onomatopoetic origin.\n',
#  'From a variant of Old Occitan [Term?], from Late Latin pausāre, present active infinitive of pausō, influenced in meaning by Latin pōnō. Compare French poser, Occitan pausar, Spanish posar, Portuguese pousar, Italian posare.\n',
#  'Borrowed from Latin praeparāre, present active infinitive of praeparō (“I prepare”).\n',
#  'From Old Occitan, from Latin *podiāre, from Latin podium. Compare Occitan pujar, Aragonese puyar, Portuguese pojar, Italian poggiare; cf. also French appuyer, Spanish apoyar, Italian appoggiare, from a Vulgar Latin *appodiāre.\n',
#  'From sacsar +\u200e -ejar.\n',
#  'From Old Occitan (compare Occitan sortir), from Latin sortīrī (“to select”) (present active infinitive of sortior), probably influenced by surrectus (through a Vulgar Latin form *surctus and its derivatives, possibly through a verb *surrectīre, surctīre; cf. also Old Catalan surt, surta).\n',
#  'From Old Occitan, from Late Latin taleare or taliāre, present active infinitive of taliō, from Latin talea.\n',
#  'From Medieval Latin, from Vulgar Latin *tirō, tirāre, from Proto-Germanic *teraną (“to tear, tear away, rip or snatch off, pull violently, tug”) (through Gothic *𐍄𐌹𐍂𐌰𐌽 (*tiran)), from Proto-Indo-European *der- (“to tear, tear apart”). Alternatively Late Latin *martyrāre, possibly with influence from Latin trahō. Compare French tirer, Italian tirare.\n',
#  'From Old Occitan, from Vulgar Latin *ungla, syncopated form of Latin ungula, from unguis, ultimately from Proto-Indo-European *h₃negʰ-.\n',
#  'From Old Czech chot, from Proto-Slavic *chotь. Related to chtít.\n',
#  'jíst +\u200e -dlo',
#  'From o- +\u200e hnout.\n',
#  'při- +\u200e vázat',
#  'From s- +\u200e chovat.\n',
#  'From s- +\u200e pojit',
#  'Compare Slovak vetva and Russian ветвь (vetvʹ).\n',
#  'From Proto-Nakh *butt.\n',
#  'From Proto-Nakh *dāli.\n',
#  'From Proto-Nakh *kōḳ.\n',
#  'From Proto-Nakh *qēra.\n',
#  'From Proto-Nakh *lātte.\n',
#  'From Proto-Nakh *moṭṭ.\n',
#  'From Proto-Nakh *pχā. Cognate with Ingush пхьан (pḥan, “hornbeam”). Associated with several weapon names, because they were made of hornbeam: Chechen пха (pχa, “arrow”), пха, пхьа (pχa, pḥa, “shield”), пхердукъ (pχerduq̇, “spear”).\n',
#  'From сан (san, “my, mine”); related to сирла (sirla, “light, bright, clear”) and серло (serlo, “light, brightness, illumination”).\n',
#  'Cognate with Ingush ха (χa). Related to Georgian ხანი (xani). This etymology is incomplete. You can help Wiktionary by elaborating on the origins of this term.',
#  'From Proto-Nakh *xi.\n',
#  'From Proto-Nakh *cħa.\n',
#  'From Proto-Nakh *c̣e (“name”).\n',
#  'From Proto-Nakh *jobq̇.\n',
#  'Borrowed from Russian обед (obed).\n',
#  'Related to Tatar апа (apa), from Old Turkic apa.\n',
#  'Compare Tatar ут (ut).\n',
#  'From Proto-Turkic *kȫk.\n',
#  'From Proto-Turkic *gīr- (“to enter”). Cognate with Old Turkic 𐰚𐰃𐰼\u200e (kir- /kir²/), Turkish girmek, Azerbaijani girmək etc.\n',
#  "From Proto-Turkic *gül. Cognate with Turkish and Azerbaijani -gil (“someone's home or family”), Yakut күүлэ (küüle, “entrance hall”).\n",
#  'From Proto-Turkic *buŕ- / *boŕ- (“to damage, destroy”). Cognate with Azerbaijani pozmaq, Bashkir боҙоу (boðou).\n',
#  'Related to Turkish bulut and Yakut пылыт (pılıt), from Proto-Turkic *bulït, .\n',
#  'From Proto-Turkic *biarŋak.\n',
#  'From Proto-Turkic *yāŕ. Cognate with Turkish yaz (“summer”).\n',
#  'Historically from тăв (tăv) (< тав (taw) < тау (tau)), from Proto-Turkic *tāg.\n',
#  'From Proto-Turkic *kāŕ, compare Turkish kaz.\n',
#  'From Proto-Turkic *dɨl.\n',
#  'From Proto-Turkic *dik- (“vertical; to to plant vertically”).\nCompare Azerbaijani dikmək (“to bury”) dik (“upright, vertical”), tikmək (“to sew”); Turkish dikmek (“to sew”), Kumyk тикмек (tikmek, “to sew; to build”) Kazakh тігу (tigw).\n',
#  'Related to Turkish diş.\n',
#  'From Proto-Chukotko-Kamchatkan *ðəlɣə (“finger”). Compare also Koryak йәлгәлӈән, Alutor тылгылӈын and Itelmen луфԓич.\n',
#  'Cognate with Japhug amdzɯ (Zhang, Jacques, and Lai, 2019).\n',
#  'Simplified from 點 (黑 → 灬). Note that 黑 changed from being on the left to being 灬, underneath. Compare 黙 (from 默), which retains the 里, and 黒, which is the simplification in isolation.\nCurrent form is graphically 占 + 灬.\n',
#  'From Proto-Sino-Tibetan *m-kul (“twenty; all”); cognate with 昆 (OC *kuːn, “swarming”), Tibetan ཀུན (kun, “all”), Burmese အကုန် (a.kun, “all”) (Benedict, 1972; STEDT).\n',
#  'From Proto-Sino-Tibetan *m/g-(r)wa-ŋ/k/t (“horn; angle; corner”) (STEDT). Cognate with Tibetan རྭ (rwa, “horn”), Garo grong (“horn”), Jingpho nrung (n̩³¹ ʒuŋ³³, “horn”), Chepang रोङः (roŋʔ, “horn”), 觡 (OC *kraːɡ, “antler”). The Tibeto-Burman *-ŋ final variant is reflected in 觥 (OC *kʷraːŋ, “drinking vessel made from animal horn”) (Schuessler, 2007). Possibly also related to 鹿 (OC *b·roːɡ, “deer”) (Sagart, 1999).\nA derivative is 餃 (“stuffed dumpling”), named for its horn-like shape (Norman, 1988).\nIt is probably unrelated with Proto-Indo-European *ḱr̥h₂nós (“horn”) ( < *ḱerh₂- (“horn”)) and Proto-Semitic *ḳarn- (“horn”) despite the phonological and semantic resemblance between the three.\n',
#  'Proto-Celtic *bawā. Compare French boue (“mud”), from Gaulish *bauā.\n',
#  'From berw (“boiling”) +\u200e -i.\n',
#  'From Middle Welsh bwrt, from Old English bord (compare Irish bord); doublet of bord.\n',
#  'From Proto-Brythonic *catarno, from Proto-Celtic *katus (“battle”). See cad.\n',
#  'From cau +\u200e -ad.\n',
#  'From cangau, plural of cainc (“branch”) (from Proto-Celtic *kankā),  +\u200e -en (singulative suffix).',
#  'From casgl (“collection”) +\u200e -u.\n',
#  "Cognate with Cornish gwari and Breton c'hoari.\n",
#  'Cognate with Cornish kelmi, Breton koulmañ.\n',
#  'From Proto-Brythonic *klüwid, from Proto-Celtic *klusīti, from Proto-Indo-European *ḱlew-.\n',
#  'Clipping of cyfodi, from cyf- +\u200e odi.\n',
#  'From Proto-Celtic *koudeti, from Proto-Indo-European *(s)kewdʰ- (“to cover, wrap, encase”),  +\u200e -io (forming verbnouns). Cognate with Cornish cuthe, Breton cuzaff, English hide, Latin custōs, Ancient Greek κεύθω (keúthō, “to conceal”), Sanskrit कुहरम् (kuharam, “cave”).\n',
#  'From cwymp.\n',
#  'From cyf- +\u200e rhif.\n',
#  'From Proto-Brythonic *dalg-, from Proto-Indo-European *delgʰ-. Cognate with Latin indulgeo.',
#  'Contraction of older deau (“right; south”), from Proto-Celtic *dexsos (“right”). Cognate with Cornish dyhow, Breton dehou, Irish deas, Scottish Gaelic deas, Manx jiass.\nThe sense "south" comes from the fact that the south is on the right-hand side of a person facing east.',
#  'Borrowed from Latin discō (“I learn”). Cognate to Breton deskiñ and Cornish dyski, from the same origin.\n',
#  'Borrowed from Old English ford',
#  'Ultimately from Proto-Indo-European *ǵʰeh₁- (“to leave behind, abandon”).',
#  'From gorchudd +\u200e -io.\n',
#  'From Old Welsh guor (“over”) +\u200e phenn (“head”) (see penn).\nCognate with Cornish gorfedna, Breton gourfennañ.\n',
#  'From Proto-Celtic *u̯o-stutā (see go-), from Proto-Indo-European *steh₂-.',
#  'From Proto-Celtic *grendsmu, from Proto-Indo-European *gʰredʰ-. Cognate with Latin gradus (“step”).\n',
#  'The variant gwddwg is cognate with Old Breton guodoc (Middle Breton gouzouc, Breton gouzoug, goûg), but it is difficult to explain the alternation between -wg, -w, and -f. The oldest form of the word cited in Geiriadur Prifysgol Cymru is the Middle Welsh plural form gedueu (13th century; = modern gyddfau), while the soft mutation forms wðwc, wddf, and wddw are all attested in the 14th century, indicating that the alternation is very old.\n',
#  'Back-formation from gwneuthur, from Middle Welsh gwneuthur, altered from *gwreithur with -n- from gwnïo (“to sew”), from Proto-Celtic *wregeti (compare Cornish gwra (“he does, makes”), Breton gra (“he does, makes”), Old Irish fairged (“they made”)), from Proto-Indo-European *werǵ- (compare English work). Middle Welsh preserved the -r- in the preterite: gwreith (“I did, made”), goruc (“he did, made”).\n',
#  'gwth +\u200e -io',
#  'From gyr (“drive, thrust; flock, drove”) +\u200e -u.\n',
#  'Cognate with Breton moan, Cornish moon.\n',
#  'Ultimately from Proto-Indo-European *med- (“measure; advise”).This etymology is incomplete. You can help Wiktionary by elaborating on the origins of this term.',
# ...
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'From Old Japanese, from Proto-Japonic *eku. Cognate with Okinawan 行ちゅん (いちゅん, ichun), Miyako 行きぃ (いきぃ, iksï).\n',
#  'Compound of 裏 (ura, “back side, inside, far side”) +\u200e 返す (kaesu, “to flip over, to turn over”). The kaesu changes to gaesu as an instance of rendaku (連濁).\n',
#  '/opu pu/ → /opopu/ → /ofofu/ → */owou/ → /oːu/From the Old Japanese verb 覆ふ (opu, “cover from above”) + ふ (-fu, auxillary verb modifier).',
#  'From Proto-Japonic *miru. Cognate with 目 (me, “eye”).\n',
#  '*/ʔiəm/ → /əmʉ/ → /omʉ/ → /oɴ/From Middle Chinese 音 (MC ʔˠiɪm).\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'From Proto-Inuit *qiʁnǝ-ʁ- (“black, dark”), from Proto-Eskimo *qiʁnǝ-ʁ- (“black, dark”).\n',
#  'From Proto-Inuit *tǝɣu- (“to take”), from Proto-Eskimo *tǝɣu- (“to take”). Compare Inupiaq tigusi-.\n',
#  'From Proto-Inuit *tǝŋǝ- (“fly up, be flying”), from Proto-Eskimo *tǝŋǝ- (“to fly up”).\n',
#  'From Proto-Inuit *ǝvvaʁ- (“take a bath, wash”).\n',
#  'From Proto-Dravidian *amma',
#  'From Proto-Dravidian *ēr̤u. Cognates include Tamil ஏழு (ēḻu).\n',
#  'From Old Kannada ಕರೆ (kare).\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'Borrowed from Sanskrit दीर्घ (dīrgha, “long”).\n',
#  'Borrowed from Sanskrit बल (bala).\n',
#  'Borrowed from Sanskrit भूमि (bhūmi).\n',
#  'Cognate with Tamil மாட்டு (māṭṭu), Telugu మాట (māṭa).\n',
#  'Borrowed from Sanskrit हिम (hima).\n',
#  'From Old Georgian დაჲ (day), from Proto-Kartvelian *da-. Cognate with Mingrelian და (da), Laz და (da) and Svan დაჲ (day), დაჩუირ (dačuir), უდილ (udil). Svan დაჲ (day) might be borrowed from Georgian rather than inherited from Proto-Kartvelian.\n',
#  'From Old Georgian ენაჲ (enay), from Proto-Kartvelian *nen-. Cognate with Svan ნინ (nin), Mingrelian ნინა (nina) and Laz ნენა (nena).\n',
#  'From Old Georgian კჳრაჲ (ḳwiray), კჳრიაკჱ (ḳwiriaḳē), from Koine Greek Κυριακή (Kuriakḗ, “Sunday”).\n',
#  'From Old Georgian საქმჱ (sakmē), საქმეჲ (sakmey), most probably from იქმს (ikms).\n',
#  'From Old Georgian სიტყუაჲ (siṭq̇uay), from Proto-Georgian-Zan *ṭq̇w-. Cognate with Mingrelian ზიტყვა (ziṭq̇va).\n',
#  'From Hittite [script needed] (šuppi, “clean”). Most likely a Proto-Kartvelian borrowing during the late, Proto-Karto-Zan stage of development (XIX-VIII centuries BC).(Can this(+) etymology be sourced?)On the other hand, according to Ačaṙean, borrowed from Iranian from a word in the family of Persian سفید\u200e (safid, “white”).\n',
#  'Related to Old Armenian տաղախ (tałax, “mortar”), Laz ტოლოფი (ṭolopi, “mud”).\n',
#  'From Old Georgian ტანი (ṭani), probably borrowed from Persian تن\u200e (tan, “body”). Compare Old Georgian ვახტანგ (vaxṭang).\n',
#  'From Old Georgian ტყავი (ṭq̇avi), from Proto-Georgian-Zan *ṭq̇aw-. Cognate with Mingrelian ტყები (ṭq̇ebi), Laz ტკები (ṭḳebi), ტები (ṭebi).\n',
#  'From Old Georgian [Term?], from Proto-Kartvelian *prcx- (“fingernail; to scratch”).\n',
#  'From Old Georgian ყელი (q̇eli), from Proto-Kartvelian *q̇el-. Cognate with Mingrelian ყალი (q̇ali), ჸალი (ʾali) and Laz ყალი (q̇ali), ალი (ali). The word is also preserved in Svan mə-q̇l-a (mə-q̇l-a).',
#  'From Old Georgian ხე (xe); see below for more.\n',
#  'From Old Georgian ჴმაჲ (qmay), from Proto-Georgian-Zan *qam-, *qm-. Cognate with Mingrelian ხუმა (xuma). For the political sense, compare Russian голос (golos).\n',
#  'From Proto-Turkic *ïgač.\n',
#  'From Proto-Turkic *āń(k) (“moon, month”). Cognate with Azerbaijani ay, Turkish, Crimean Tatar ay, Tatar, Bashkir, Kyrgyz ай (ay), Southern Altai ай (ay), Uzbek oy, etc.\n',
#  'Cognate to Azerbaijani alov and Turkish alev.\n',
#  'From Proto-Turkic *agrɨ-g (“pain, illness”), an action noun of *agrɨ- (“to ache; be ill”).\nCognate with\nKarakhanid اَغْرِغْ\u200e (aɣrïɣ, “pain”),\nOld Uyghur ՚՚q̈ryq (aɣrïɣ, “pain, illness”), Kyrgyz оору (ooru), Southern Altai оору (ooru),\nUzbek ogʻriq (“pain, ilness”),\nUyghur ئاغرىق\u200e (aghriq, “illness”),\nKhakas ағырығ (ağırığ, “illness; ill”),\nTuvan аарыг (aarıg, “illness, pain”),\nYakut ыарыы (ıarıı, “pain, disease”),\nTurkish ağrı (“pain, ache”), etc.\n',
#  'From Proto-Turkic *adak (“foot, end”).\n',
#  'Borrowed from Persian هنگامه\u200e (hangâme). Cognate with Bashkir әңгәмә (äñgämä), Kyrgyz аңгеме (añgeme), Uzbek hangama (“id.”), etc.\n',
#  'From Proto-Turkic *bar- (“to walk, go; to come, reach”). Cognate with Turkish varmak.\n',
#  'From Common Kypchak bawïr, from Proto-Turkic *biagɨr (“liver”). Cognate with Old Uyghur baγarsuq (“intestines, viscera”), Turkish bağırsak (“intestine”), etc.\n',
#  'Cognate with Tatar тавыш (tawış),\nBashkir тауыш (tawïš),\nKarakalpak даўыс (dawıs),\nKarachay-Balkar таууш (tauuş),\nKyrgyz тоош (tooş),\nUzbek tovush,\nUyghur تاۋۇش\u200e (tawush),\nCrimean Tatar davuş,\nKhakas табыс (tabıs, “voice, sound”).\n',
#  'From Proto-Turkic *de- (“to say”). Cognate with Azerbaijani demək, Turkish demek.\n',
#  'Cognate with Azerbaijani eşitmək, Uzbek eshitmoq.\n',
#  'Ultimately from Proto-Turkic *yạŕ- (“to write”). Cognate with Azerbaijani yazmaq, Uzbek yozmoq, etc.\n',
#  'From Proto-Turkic *yaŋï, *yeŋi (“new”).\n',
#  'Cognate with Azerbaijani gülmək, Uzbek kulmoq.\n',
#  'From Proto-Turkic *gün (“sun, day”).\n',
#  'From Common Turkic *kač- (“to run away, flee”).\n',
#  'From Proto-Turkic *Kol.\n',
#  'From Proto-Turkic *okï-.\n',
#  'From Proto-Turkic *ol-tur- (“to sit”).\n',
#  'Cognate with Azerbaijani oyanmaq, Uzbek uygʻonmoq.\n',
#  'Cognate with Azerbaijani ölmək, Uzbek oʻlmoq.\n',
#  'From Proto-Turkic *siaŕ (“swamp, marsh”).\nCognate with\nBashkir һаҙ (hað), Kyrgyz, Tatar саз (saz),\nUzbek soz,\nSouthern Altai, Khakas сас (sas, “swamp, marsh”);\nChuvash шур (šur, “swamp, marsh”),\netc.\n',
#  'From Proto-Turkic *sạk (“aware, alert”).\n',
#  'From Proto-Turkic *sōl (“left”).\n',
#  'From Proto-Turkic *söŕ.\n',
#  'From Common Kipchak *süy-, from Proto-Turkic *seb- (“to love”). Cognate with Turkish sev-, etc.\n',
#  'Ultimately from Proto-Turkic *dart- (“to pull; to hang”). Cognate with Azerbaijani dartmaq.\n',
#  'From Proto-Turkic *dil (“tongue; language”).\nCognate with\nTatar тел (tel),\nBashkir тел (tel),\nKyrgyz тил (til),\nUzbek til,\nTurkish dil (“tongue, language”).\n',
#  'From a Mongolic source, from Proto-Mongolic *töle- (“to pay”).\nCognate with\nOld Uyghur [script needed] (tölä-, “to pay”);\nBashkir түләү (tüläw), Kyrgyz төлөө (tölöö), Uzbek toʻlamoq, Uyghur تۆلىمەك\u200e\u200e (tölimek\u200e),\nKhakas тӧле- (tӧle-), Tuvan төлээр (töleer, “to pay”).\n',
#  'From Proto-Turkic *dur- (“to stand”). Cognate with Turkish durmak, Turkmen durmak, Crimean Tatar turmak, Uzbek turmoq, Uyghur تۇرماق\u200e (turmaq), Azerbaijani durmaq, Tatar turu, Chuvash тӑр (tăr), etc.\n',
#  'From Proto-Turkic *iak- (“to flow”). Related to Turkish akmak.\n',
#  'From Proto-Uralic *küje.\n',
#  'From Proto-Permic *śoj (compare Komi-Permyak and Komi-Zyrian сёй (sjoj)), from Proto-Uralic *śajwa.\n',
#  'From Proto-Mongolic *ayu-, with assimilation found in most modern languages.\nCompare Dongxiang ayi, (perhaps somehow related) Old Turkic [script needed] (ayïn-, “to fear”).\n',
#  'From Proto-Mongolic *arasun, with unexplained palatalization. Compare Dongxiang arasun (“skin, husk”).\n',
#  'From Proto-Mongolic *barï-, compare Dongxiang barei.\n',
#  'From Classical Mongolian ᠪᠠᠶ᠋ᠠᠯᠢᠭ (bay᠋alig), from Middle Mongolian [Term?]; equivalent to бая- (baja-) +\u200e -лаг (-lag). Cognate with Buryat баялиг (bajalig), Kalmyk байлг (baylg), etc.\n',
#  'From Classical Mongolian ᠪᠡᠶ᠌\u180eᠡ᠋ (bey᠌-e᠋), from Middle Mongolian [Term?], from Proto-Mongolic *beje. Cognate with Buryat бэе (beje), Kalmyk бий (biy), etc. Compare also Yakut бэйэ (beye, “body; self”), Manchu ᠪᡝᠶᡝ (beye, “body”), Evenki бэе (bəje, “body; person”), etc.\n',
#  'From Proto-Mongolic *bol- (“to become”). Akin to Proto-Turkic *bōl- (“to become”), compare Turkmen bōlmak (“to become”), Turkish olmak (“to become, happen”).\n',
#  'From Proto-Mongolic *boxa-, from Proto-Turkic *bog-.\nCompare East Yugur puu, Turkish boğmak.\n',
#  'From Proto-Mongolic *bos-, compare Dongxiang bosi.\n',
#  'From Proto-Mongolic *budaxan, perhaps related to Proto-Turkic *botka (“gruel”).\nCompare Dongxiang budan, Bashkir бутҡа (butqa), Chuvash пӑтӑ (pătă).\n',
#  'From Proto-Mongolic *gar, commonly connected with Proto-Turkic *kar, *karɨ (“forearm”) or Proto-Tungusic *gara (“branch, bough”).\nCompare Dongxiang kha, Daur gary, Kazakh қар (qar), Tuvan кыры (kırı, “ulna”), Evenki гара (gara), Manchu ᡤᠠᡵᡤᠠᠨ (gargan).\n',
#  'Compare Buryat гэр (ger), Kalmyk гер (ger).\n',
#  'From Proto-Mongolic *daxula-, compare Dongxiang daola.\nEquivalent to дуу (duu, “song, voice”) +\u200e -лах (-lah).\n',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'See Chinese 站 (zhàn, “(post) station”).\n',
#  'From Proto-Mongolic *jasa-, compare Mongghul sza (“make, repair”).\nTurkic forms of the word (see Turkish yasamak) are considered Mongolisms, relation with Manchu ᡩᠠᠰᠠᠮᠪᡳ (dasambi, “to govern”), if any, is unclear.\n',
#  "Attested once in a 1338 Middle Mongolian document as ᠵᠣᠭᠰᠤᠭᠤᠯᠪᠠᠰᠤ (ǰoɣsuɣulbasu, “(if he) let (them) stop”), but otherwise restricted to modern Central Mongolic.\nCognate with Buryat зогсохо (zogsoxo), Kalmyk зогсх (zogsx).\nReplaced Proto-Mongolic *baï- in the sense 'to stand', see байх (bajh, “to be”).\n",
#  'Proto-Mongolic *jaxu-, compare Dongxiang zhao.\n',
#  'From Classical Mongolian ᠮᠣᠳᠤ (modu), from Middle Mongolian [Term?], Proto-Mongolic *modu. Cognate with Buryat модо- (modo-), Kalmyk мод- (mod-), Dongxiang mutun, etc.\n',
#  'From Proto-Mongolic *meŋgün, compare Dongxiang miengu.\nPerhaps related to Western Yugur menek (“money”), Arghu بَنَكْ\u200e (benek, “small copper coin”) identified by Clauson with Common Turkic *benek (“spot, speck, freckle”) from Persian بنک\u200e (banak, “seed, pimple”)  (perhaps influenced by *beŋ (“birthmark”)). See Turkish benek.\n',
#  'From Proto-Mongolic *möre (“shoulder”), perhaps related further with Proto-Tungusic *muire.\nCompare Daur mur, Evenki мирэ (mirə), Nanai нгуйрэ.\n',
#  'Inherited from Proto-Mongolic *narïn, compare Dongxiang narun, Daur naring.\n',
#  'From Proto-Mongolic *nökör, compare Dongxiang nokie.\n',
#  'From Proto-Mongolic *nigen, *niken.\n',
#  'From Proto-Mongolic *ökin (“daughter”). Compare Buryat үхин (üxin) and Dongxiang ojin.\n',
#  'From Proto-Mongolic *ebed-, compare Mogholi ebetku.\n',
#  'From Proto-Mongolic *ebesün, compare Dongxiang osun.\n',
#  'From Proto-Mongolic *ög-. Cognate to Dongxiang ogi and perhaps Khitan [Khitan Small needed] (û).\n',
#  'From Proto-Mongolic *sabar, compare Mongghul sawar.\n',
#  'From Proto-Mongolic *sara more distantly related to Khitan 賽咿児 (sair)',
#  'From Proto-Mongolic *saxu-, compare Dongxiang sao, Daur saugw.\n',
#  'Ultimately from Proto-Turkic *sürüg (“flock, herd”), equivalent to *sür- (“to drive”) +\u200e *-g. Compare Turkish sürü.\n',
#  'From Proto-Mongolic *talbï- (“to free”), compare Daur taly-.\nThe evolution of senses from “to release” > “to place” is shared with Chinese 放 (fàng).\n',
#  'From Proto-Mongolic *toguxan, compare Dongxiang tughon.\n',
#  'From Proto-Mongolic *töle-, compare East Yugur tölö.\n',
#  'From Proto-Mongolic *texü-, compare Dongxiang qiao.\n',
#  'From Proto-Mongolic *teŋgeri, from Proto-Turkic *teŋri, compare Old Turkic 𐱅𐰭𐰼𐰃\u200e (teŋri, “sky”).\n',
#  'From Classical Mongolian ᠲᠡᠷ\u180eᠡ᠋ (ter-e᠋, “that”), from Middle Mongolian ᠲᠡᠷᠡ (tere) and ᠲᠡᠷ\u180eᠡ᠋ (ter-e᠋, “that”), from Proto-Mongolic *tere (“that”). Cognate with Buryat тэрэ (tere, “that”), Kalmyk тер (ter, “that; he, she, it”), Dongxiang tere, etc.\nReplaced original ᠢ (i, compare Daur ing) for sense ‘he, she, it’ as the third-person singular pronoun.\n',
#  "From Classical Mongolian ᠤᠯᠤᠰ᠋ (ulus᠋), from Middle Mongolian ᠤᠯᠤᠰ᠋ (ulus᠋), from Common Turkic *uluš (“country; city”). Compare Buryat улас (ulas), Kalmyk улс (uls); Old Uyghur 'wlwš (uluš, “country”); etc.\n",
#  'From Proto-Mongolic *urtu, compare East Yugur hurtu, Daur ort.\n',
#  'From Proto-Mongolic *hüjüxür, compare Dongxiang uzhu, Daur xujuur.\n',
#  'From Proto-Mongolic *ünen, compare Daur unung.\n',
#  'хаах (haah, “to close, to block”) +\u200e -лга (-lga)',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'Cognate with Buryat хаяха (xajaxa) and Kalmyk хайх (xayx). Not found outside Central Mongolic.\n',
#  'From Proto-Mongolic *koxalaï (“throat”).\n',
#  'From Proto-Mongolic *ködel-, compare Mongghul ghudili, Dongxiang gojielu.\n',
#  'From Proto-Mongolic *köl, perhaps related with Proto-Turkic *kol (“arm”).\nCompare Dongxiang kon, Turkish kol.\n',
#  'from Proto-Mongolic, borrowed or cognate with Proto-Turkic *kȫk, compare with Turkish gök and Evenki куку (kuku, “sea-coloured”).\n',
#  'From Proto-Mongolic *kïmusun, compare Dongxiang ghimusun (“nail, hoof”).\n',
#  'From Proto-Mongolic *kuruxun, compare Dongxiang ghurun.\n',
#  'From Proto-Mongolic *küjüxün, compare Dongxiang ghuzhun, Daur xujuu.\n',
#  'Cognate with Buryat хүлеэхэ (xüljeexe), Kalmyk күләх (küläx).\n',
#  'From Proto-Mongolic *kürje(g), from Proto-Turkic *küre-ček.\nCompare Mangghuer kuerji, Turkish kürek.\n',
#  'From Proto-Mongolic *köw.\n',
#  'From Proto-Mongolic *kelen, compare Dongxiang kielien.\n',
#  'From *kele-, a haplological variant of Proto-Mongolic *kelele-, equivalent to хэл (hel, “tongue, language”) +\u200e -лэх (-leh).\nCompare Dongxiang kielie.\n',
#  'From Proto-Turkic *käräk (“necessity”), from earlier *kärgäk. \nSome senses might be from *хэрэх (*hereh) +\u200e -г (-g), with unattested *хэрэх (*hereh) being also the root of хэрүүл (herüül, “quarrel”) and хэрэлдэх (hereldeh, “to quarrel”).\n',
#  'From Proto-Mongolic *cagaxan, compare Dongxiang chighan.\n',
#  'From Proto-Mongolic *cokï- (“to peck”), from Proto-Turkic *čok- (“to swoop down on, to peck”). Evolution of sense to more general to hit is shared with other Central Mongolic languages and Daur.\nCompare Dongxiang chughu, Kazakh шоқу (şoqw).\n',
#  'From Proto-Mongolic *cexeji, compare Mogholi caiji.\n',
#  'From Tibetan ཤེལ (shel).\n',
#  'эргэх (ergeh, “to turn”) +\u200e -уулах (-uulah)',
#  'From Proto-Mongolic *erexün, compare Daur eruu.\n',
#  'эх (eh, “beginning, origin”) +\u200e -лах (-lah)',
#  '(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)',
#  'From Proto-Iranian *ātr-, from Proto-Indo-Iranian *ātar-, from Proto-Indo-European *h₂eh₁ter- (“fire”). Compare Persian آذر\u200e (âzar), Avestan 𐬁𐬙𐬀𐬭𐬱\u200e (ātarš, “fire”), Ossetian арт (art), Pashto اور\u200e (or); compare also Old Armenian այրեմ (ayrem), Serbo-Croatian vatra, Irish áith (“kiln”), Welsh odyn, Umbrian 𐌀𐌈𐌓𐌖 (atru), and Latin āter, which may be derived from the same ultimate root.\n',
#  'From Proto-Iranian [Term?] (compare Avestan 𐬬𐬁𐬙𐬋\u200e (vātō), Pashto and Persian باد\u200e (bâd)), from Proto-Indo-Iranian [Term?] (compare Sanskrit वात (vā́ta)), from Proto-Indo-European *h₂wéh₁n̥ts (“blowing”), present participle of *h₂weh₁- (“to blow”).\n',
#  'Borrowed from Arabic مِسْمَار\u200e (mismār).\n',
#  'Related to Persian بودن\u200e (bûdan).\n',
#  'From Persian چند\u200e (čand).\n',
#  'Related to Persian چرم\u200e (čarm).\n',
#  'From Proto-Indo-European *kyew- (“to move, go”). Cognates include Persian شدن\u200e (šodan, “to become”), Ossetian цӕуын (cæwyn), Pashto شول\u200e (šwəl), Sanskrit च्य्अवते (cyávate, “move to and fro, stir”), Old Armenian չու (čʿu) and Ancient Greek σεύω (seúō, “put in quick motion, drive”).\n',
#  'From Proto-Iranian *dr̥Hgáh, from Proto-Indo-Iranian *dr̥Hgʰás, from Proto-Indo-European *dl̥h₁gʰós. Compare Persian دراز\u200e (dirāz), Sanskrit दीर्घ (dīrgha).\n',
#  'Related to Persian گفتن\u200e (goftan).\n',
#  ...]

# %%
import re

for element in etymologies:
    print(element)
    print(re.findall(r'from ([A-Z]\w+|[A-Z]\w+\-[A-Z]\w+) \w+', element))
# Out:
# Cognate with Abaza адгьы́л (ādg̍ə́l); compare Georgian ადგილი (adgili).
#
# []
# Compare Old Armenian պինչ (pinčʿ).
#
# []
# Cognate with Adyghe лъэ (łă).
#
# []
# From Proto-Circassian *gʷǝ (“heart”).
#
# []
# From Proto-Circassian *ʐə.
#
# []
# From Proto-Circassian zə.
#
# []
# From Proto-Circassian *kʲʼa.
#
# []
# тхьамыкӏ (tḥāməč̣̍) +‎ -гъу (-ġ°)
# []
# From Proto-Circassian *ɕʷa
# []
# From Proto-Circassian *t͡ʂʰə (“horse”).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From the root ء ث ر‎ (ʾ-ṯ-r).
#
# []
# From the root ح ب ب‎ (ḥ-b-b).
#
# []
# From the root د و ر‎ (d-w-r).
#
# []
# From Proto-Semitic *ʾakal- (root ء ك ل‎ (ʾ-k-l)).
#
# []
# From the root و ق د‎ (w-q-d).
#
# []
# From root ن ظ ر‎ (n-ẓ-r)
# []
# From the root ق ط ع‎ (q-ṭ-ʿ).
#
# []
# From Proto-Semitic *bint-. Has the Semitic feminine suffix *-at added to the root *bin- of اِبْن‎ (ibn, “son”).
#
# []
# From root ب ي ت‎ (b-y-t). From Proto-Semitic *bayt-.
#
# []
# Originally a case form of a defective noun تَحْت‎ (taḥt, “location that is below”); see the usage note. From the root ت ح ت‎ (t-ḥ-t).
#
# []
# From the root ت ر ك‎ (t-r-k).
#
# []
# From the root ك ل م‎ (k-l-m)
# []
# Synchronically from the root ت ل ل‎ (t-l-l). Ultimately from Proto-Semitic *tall- (“hill”).
#
# []
# Mediopassive of وَقَّفَ‎ (waqqafa, “to stop (transitive), to bring to a stop”), from the root و ق ف‎ (w-q-f); compare وَقَفَ‎ (waqafa, “to stop (intransitive)”).
#
# []
# From the root ج ل س‎ (j-l-s)
# []
# From the root ج م ل‎ (j-m-l).
#
# []
# From the root ح و ف‎ (ḥ-w-f).
#
# []
# From the root ح ب ب‎ (ḥ-b-b).
#
# []
# From the root ح ض ر‎ (ḥ-ḍ-r).
#
# []
# From the root ح م ل‎ (ḥ-m-l).
#
# []
# From the root ح م ي‎ (ḥ-m-y).
#
# []
# From the root خ ب ز‎ (ḵ-b-z).
#
# []
# Derived from the active participle of the verb دَرَّ‎ (darra, “to flow copiously”), from the root د ر ر‎ (d-r-r).
#
# []
# From the root د ب ب‎ (d-b-b).
#
# []
# From the root د خ ل‎ (d-ḵ-l).
#
# []
# From the root د ف ع‎ (d-f-ʿ).
#
# []
# From the root د ل ل‎ (d-l-l).
#
# []
# From the root ذ و ب‎ (ḏ-w-b)
# []
# From the root ذ ه ب‎ (ḏ-h-b).
#
# []
# From the root ر ب ط‎ (r-b-ṭ).
#
# []
# From the root ر ع د‎ (r-ʿ-d).
#
# []
# From the root ر ف ع‎ (r-f-ʿ).
#
# []
# From the root س و ق‎ (s-w-q).
#
# []
# From the root س ح ب‎ (s-ḥ-b).
#
# []
# From the root س م ع‎ (s-m-ʿ), from Proto-Semitic *šamaʿ-.
#
# []
# From the root س ن ن‎ (s-n-n).
#
# []
# From the root ش ر ق‎ (š-r-q).
#
# []
# From the root ش ع ر‎ (š-ʿ-r).
#
# []
# From the root ص خ ب‎ (ṣ-ḵ-b).
#
# []
# From the root ص غ ر‎ (ṣ-ḡ-r), from Proto-Semitic *ṣ-ɣ-r (“to be small, young”). Cognate with Akkadian 𒌉 (TUR, ṣehru), 𒌉𒁕 (BÀN.DA, ṣehru, “small, young”), Aramaic ܙܥܘܪܐ‎ (zʿūrā, “small”), Ugaritic 𐎕𐎙𐎗 (ṣġr), Hebrew צָעִיר‎ (tsa'ír).
#
# []
# From the root ص ق ع‎ (ṣ-q-ʿ).
#
# []
# From the root ص و ت‎ (ṣ-w-t). The sense “vote” is probably a loan translation from a European language, most likely French voix, but compare also German Stimme and stimmen, Russian голос (golos) and голосовать (golosovatʹ), etc.
#
# []
# From the root ض ر ب‎ (ḍ-r-b).
#
# []
# From the root ظ ف ر‎ (ẓ-f-r), inherited from Proto-Semitic *θ̣upr-, *θ̣ipr-.
#
# []
# From the root ظ ه ر‎ (ẓ-h-r).
#
# []
# From the root ع ل م‎ (ʿ-l-m).
#
# []
# From the root ع م ل‎ (ʿ-m-l). The grammatical “government” meaning is a semantic loan from  Medieval Latin vīs. Compare Hebrew עָמָל‎ (`Amal, “work, deed”)
# []
# From the root غ ر ب‎ (ḡ-r-b).
#
# []
# From the roots غ ط ي‎ (ḡ-ṭ-y) and غ ط و‎ (ḡ-ṭ-w). Cognate with Hebrew עָטָה‎ (ʿatá).
#
# []
# From the root غ ن ي‎ (ḡ-n-y), to be free from want, to be rich, to be full; to be full of sound, resonating.
#
# []
# From the root ف ع ل‎ (f-ʿ-l); cognate with Hebrew פָּעַל‎ (pa'ál, “to do”).
#
# []
# From the root ف ه م‎ (f-h-m).
#
# []
# From the root ق و م‎ (q-w-m). Compare Hebrew קָם‎ (kam), Ge'ez ቆመ (ḳomä).
#
# []
# From the root ق د ر‎ (q-d-r).
#
# []
# From the root ق ذ ر‎ (q-ḏ-r).
#
# []
# From the root ق س م‎ (q-s-m).
#
# []
# From the root ق ط ع‎ (q-ṭ-ʿ).
#
# []
# From the root ق ل ب‎ (q-l-b).
#
# []
# From the root ق و و‎ (q-w-w).
#
# []
# From the root ك ث ر‎ (k-ṯ-r). Adverbial accusative of كَثِير‎ (kaṯīr, “many”).
#
# []
# From the root ك س ر‎ (k-s-r), related to breaking.
#
# []
# From the root ك ن س‎ (k-n-s). In Fraenkel’s and Nöldeke’s view the meaning “to sweep” is from  Aramaic כְּנַשׁ‎ / ܟܢܝ‎ (knaš, “to gather; to sweep”), denominal via مِكْنَسَة‎ (miknasa, “broom”). Note Mehri kənūs (“to sweep”).
#
# []
# From the root ل ع ب‎ (l-ʿ-b).
#
# []
# From the root ل و ح‎ (l-w-ḥ). Cognate with Hebrew לוּחַ‎ (lúakh).
#
# []
# From the root خ ل ب‎ (ḵ-l-b).
#
# []
# From the root م ر ض‎ (m-r-ḍ).
#
# []
# Derived from the passive participle of اِسْتَنْقَعَ‎ (istanqaʿa, “to be or become stagnant”), from the root ن ق ع‎ (n-q-ʿ).
#
# []
# From the root م س ك‎ (m-s-k).
#
# []
# From the root م ش ط‎ (m-š-ṭ). Compare Akkadian 𒄑𒂵𒍮 (/mušṭu/, “comb”).
#
# []
# From Proto-Semitic *malk-. Cognate to Hebrew מֶלֶךְ‎ (mélekh, “king”) and מָלַךְ‎ (malákh, “to rule”), and Aramaic מַלְכָּא‎ (malkā, “king”) and מְלַךְ‎ (m'laḵ, “to rule”).
#
# []
# From the root ن و م‎ (n-w-m).
#
# []
# From the root ن ظ ر‎ (n-ẓ-r).
#
# []
# From the root و ص ل‎ (w-ṣ-l).
#
# []
# From the root و ض ع‎ (w-ḍ-ʿ)
# []
# From the root و ل د‎ (w-l-d), from Proto-Semitic *walad-. Cognate with Akkadian 𒅇𒌅 (walādum), Aramaic יְלַד‎ (yəlaḏ), Classical Syriac ܝܠܕ‎ (ilaḏ), Hebrew יָלַד‎ (yālaḏ) and Ugaritic 𐎊𐎍𐎄 (yld).
#
# []
# From Arabic كَرَّة‎ (karra).
#
# []
# Compare Old Armenian մագիլ (magil).
#
# []
# From Proto-Avaro-Andian *c̣aʔi, from Proto-North Caucasian *c̣ăjɨ̆.
#
# ['Proto-North']
# From Proto-Turkic *ïgač.
#
# []
# From Common Turkic *ālda (“to deceive, fool”), a derivation from Common Turkic *āl (“craftiness; lie; strategy; way of doing”) , whence also dialectal Azerbaijani al (“lie, untruth”).
#
# ['Common']
# From Proto-Turkic *ạl- (“to take”). Cognate with Old Turkic 𐰞‎ (al-) Turkish almak, Chuvash ил (il), etc.
#
# []
# From Proto-Turkic *ạt- (“to throw, shoot”). Cognate with Turkish atmak.
#
# []
# From Proto-Turkic *iak- (“to flow”). Cognate with Old Turkic [script needed] (ak-), Turkish akmak, Chuvash юх (juh).
#
# []
# From Proto-Turkic *āń(k). Cognate with Chuvash уйӑх (ujăh) See Turkish ay for more cognates.
#
# []
# From bağ +‎ -la. Cognate with Turkish bağlamak.
#
# []
# Equivalent to baş (“head”) +‎ -la. Cognate with Turkish başlamak. Probably from Proto-Turkic, compare Chuvash пуҫла (puśla, “to start”, transitive).
#
# []
# From bataq +‎ -lıq.
#
# []
# From Proto-Turkic *bat- (“to sink; to fit into, get into”). Cognate with Kazakh бату (batw).
#
# []
# From Proto-Turkic *bạk- (“to look, watch”). Cognate with Turkish bakmak, Crimean Tatar baqmaq, Turkmen bakmak.
#
# []
# From Proto-Turkic *bil- (“to know”)
# Cognate with
# Old Turkic 𐰋𐰃𐰠‎ (bil-, “to know”),
# Turkish bilmek,
# Crimean Tatar bilmek,
# Uzbek bilmoq (“to know”).
# Crimean Tatar bilmek,
# Kazakh білу (bilw, “to know”),
# Tatar белү (belü)
# []
# Morphologically bişmək (“become cooked”) +‎ -ir (“causative suffix”). Cognate with Turkish pişirmek (“to cook”), Kazakh пісіру (pisirw, “to cook”), Tatar пешерү (peşerü, “to cook, to boil”), Uyghur پىشىرماق‎ (pishirmaq, “to cook”).
#
# []
# From Proto-Turkic *büt-, whence also bütün (“all, whole”). Cognate with Turkish bitmek, Chuvash пӗт (pĕt) etc.
#
# []
# Ultimately from Sinitic 茶.
#
# ['Sinitic']
# From Proto-Turkic *čebir-. Cognate with Chuvash ҫаврӑн (śavrăn).
#
# []
# From Common Turkic *čeŋe. Cognate with Turkish çene, see there for more.
#
# []
# Borrowed from Persian چنگال‎ (čangâl).
#
# ['Persian']
# From Proto-Turkic *čẹr (“rotten, foul; to rot; illness; dirt; to be sick, ill; rot; glue; anguish, sorrow”), whence possibly also Azerbaijani çirk (“dirt”). Cognate with Turkish çürümek.
#
# []
# From Old Anatolian Turkish [script needed] (danışmaq), ultimately a derivation of Proto-Turkic *tạnu- (“to know, get to know”) , whence also Azerbaijani tanımaq. Cognate with Karakhanid تَنُشْماقْ‎ (tanušmāq, “to talk to each other”), Ottoman Turkish طانشمق‎ (danışmak, “to advice, counsel”).
#
# []
# From Proto-Turkic *dẹri (“skin”). Cognate with Turkmen deri, Turkish deri,
# Kazakh терi (teri),
# Karachay-Balkar тери (teri), Kumyk тери (teri), Kyrgyz тери (teri),
# Uzbek teri,
# Uyghur تېرە‎ (tëre),
# Yakut тирии (tirii), Dolgan тирии, Tatar тире (tire) and
# Bashkir тире (tire).
#
# []
# From Proto-Turkic *dil, *dɨl (“tongue; language”). Cognate with Turkish dil.
#
# []
# From Proto-Turkic *tog-. Cognate with Old Turkic [script needed] (tugur-, “to give birth to”), Uzbek tugʻmoq (“to give birth to”), Chuvash ту (tu).
#
# []
# From Proto-Turkic *duj- (“to perceive (by ears or nose), notice”). Cognate with Turkish duymak.
#
# []
# From Proto-Turkic *tüŕ (“even, level”).
#
# []
# From Proto-Turkic *ẹĺit-. Cognate with Turkish işitmek, Kazakh есту (estw), Uzbek eshitmoq.
#
# []
# From Proto-Turkic *ēt-. Cognate with Old Turkic 𐰃𐱅‎ (et-, “to make”), Turkish etmek.
#
# []
# From Proto-Turkic *eb (“dwelling place, house”). Cognate with Old Turkic 𐰋‎ (eb), Turkish ev.
#
# []
# From  Proto-Turkic *ẹri-. Cognate with Turkish erimek.
#
# []
# Ultimately from Proto-Turkic *kē(y)t- (“to go (away), to get away”).
#
# []
# From Proto-Turkic *kīr- (“to enter”). Cognate with Old Turkic 𐰚𐰃𐰼‎ (kir- /kir²/), Turkish girmek, Chuvash кӗр (kĕr) etc.
#
# []
# From gizləmək +‎ -t.
#
# []
# From gör (“to see”) +‎ -ün (“[passive suffix]”). Compare Turkish görünmek.
#
# []
# From Proto-Turkic *kȫk (“blue, green”).
#
# []
# From Arabic هَوَاء‎ (hawāʾ).
#
# []
# From Proto-Turkic *īĺč (“work, deed”).
#
# []
# From Persian کنار‎ (kenâr).
#
# []
# From Arabic مَسَافَة‎ (masāfa).
#
# []
# Cognate with Turkish ödemek, etc.
#
# []
# From Proto-Turkic *bōl- (“to become”). See there for cognates.
#
# []
# From Proto-Turkic *ört- (“to cover”), whence also Azerbaijani örpək (“headscarf”).
# Cognate with Turkish örtmek (“to cover, shut”), Chuvash витме (vitme, “to cover, protect, close”), etc.
#
# []
# From Proto-Turkic *ol-tur- (“to sit”), causative of *ol-.
#
# []
# From Proto-Turkic *okï-.
#
# []
# Ultimately from Proto-Turkic *oj- (“to play, to jump”), whence also the derivation oyun (“play, game”). Cognate with
# Turkish oynamak,
# Turkmen oýnamak,
# Crimean Tatar oynamaq,
# etc.
#
# []
# Ultimately from Proto-Turkic *ȫ- (“to think of, understand, realize”), and its derivations, such as Proto-Turkic *ȫg (“mind, thought, intelligence”), and Proto-Turkic *ȫgre-, its reflexive form. Cognate with Turkish öğretmek (“to teach”) and Turkish öğrenmek (“to learn”). See there for more.
#
# []
# From Proto-Turkic *buŕ-, *boŕ- (“to damage, destroy”).
# Cognate with Turkish bozmak, Chuvash пӑс (păs, “break, destroy”), etc.
#
# []
# From Proto-Turkic *kāpuk (“bark; skin; shell”).
#
# []
# From Common Turkic *kač- (“to run away, flee”). Cognate with Turkish kaçmak etc.
#
# []
# Morphologically from qalxmaq (“to rise”) +‎ -dır, with /x/ in qalxmaq being lost via syncope. Cognate with Turkish kaldırmak.
#
# []
# From Proto-Turkic *kaŕgan, compare Chuvash хуран (huran).
#
# []
# From Proto-Turkic *kïr- (“to break, demolish; small; to scrape, shave”). Compare Azerbaijani qırxmaq (“to shave”) which is probably a derivation from the same root. Cognate with Turkish kırmak etc.
#
# []
# From Proto-Turkic *kï̄ŕ (“girl, woman”). Cognate with Bashkir ҡыҙ (qïð), Crimean Tatar qız, Karakalpak qız, Kazakh қыз (qız), Kyrgyz кыз (kız), Old Turkic [script needed] (kïz), Ottoman Turkish قیز‎, Tatar кыз (qız), Turkish kız, Turkmen gyz, Tuvan кыс (kıs), Uyghur قىز‎ (qiz), Uzbek qiz.
#
# []
# From Proto-Turkic *kol (“upper arm”). Cognate with Turkish kol, Crimean Tatar qol etc.
#
# []
# From qop- (“to break off”) +‎ -ar
# []
# Form Common Turkic *kōrï-. Cognate with Old Turkic [script needed] (korï-, “to protect”), Uzbek qoʻrimoq (“to protect”).
#
# []
# Likely from Proto-Turkic. Cognates include Turkish korkmak, Kazakh қорқу (qorqw), Uzbek qoʻrqmoq, Chuvash хӑра (hăra).
#
# []
# From Proto-Turkic *ko-. Cognate with Old Turkic [script needed] (kōd-), [script needed] (kōt-, “to put, to set down, to lay, to place”), Turkish koymak, etc.
#
# []
# From Proto-Turkic *kūrt.
#
# []
# From Arabic صَبَاح‎ (ṣabāḥ).
#
# []
# From Old Anatolian Turkish [script needed] (sakla-, “to guard, protect”), ultimately from Proto-Turkic *sạk (“aware, alert”). Cognate with Turkish saklamak.
#
# []
# Ultimately from Arabic شَيْء‎ (šayʾ).
#
# ['Arabic']
# From Proto-Turkic *ses. Cognate with Turkish, Crimean Tatar, Gagauz, Turkish ses, Kazakh сес (ses), Chuvash сасӑ (sasă).
#
# []
# From sın- (“to break”) +‎ -dır (“causative”).
#
# []
# From Proto-Turkic *soŋ (“back, end”). Compare Turkish son below.
#
# []
# A derivation of Proto-Turkic *soŋ (“end”), whence also son. Cognate with Turkish sonra etc.
#
# []
# From Proto-Turkic *sok- (“to pierce, stick into”), which was homonyms to and possibly cognate with Proto-Turkic *sok- (“to hit, beat, crush”). Compare Karakhanid سُقْماق‎ (suqmāq), Turkish sokmak (“to insert”), etc.
#
# []
# From Proto-Turkic *sogï-k. Cognate with Turkish soğuk, Uzbek sovuq, Bashkir һыуыҡ (hïwïq), Chuvash сивӗ (sivĕ) etc.
#
# []
# From Proto-Turkic. Cognate with Turkish süpürmek, Chuvash шӑпӑр (šăpăr, “broom”).
#
# []
# Ultimately from Proto-Turkic *sǖr-, cognate with Turkish sürmek.
#
# []
# Cognate with Old Turkic [script needed] (sürüg).
#
# []
# From Proto-Turkic *tepö.
#
# []
# From Proto-Turkic *dik- (“vertical; to to plant vertically”).
# Compare Turkish dikmek (“to sew”), Kumyk тикмек (tikmek, “to sew; to build”) Kazakh тігу (tigw).
#
# []
# From Proto-Turkic *tut- (“to grasp”).
# Cognate with Old Turkic 𐱃𐰆𐱃‎ (tut-, “to keep, catch, own”), Turkish tutmak (“to catch, keep”), Bashkir тотоу (totou, “to keep, hold”), Chuvash тытма (tytma, “to keep, hold”), Khakas & Shor тударға (tudarğa, “to keep, hold, catch, seize, rule, hold back”), Kyrgyz тутуу (tutuu, “to catch”), Turkmen tutmak (“to hold, keep, catch, hire, fill”), Tuvan тудар (tudar, “to hold, catch, grab”), Uzbek tutmoq (“to take, hold, catch”), Yakut тут (tut, “to hold, seize, grab, catch”).
#
# []
# From Proto-Turkic *uŕɨ-n, *uŕa-k (“long, far, late”), whence also uzaq (“far, distant”).
#
# []
# Ultimately from Proto-Turkic *bēr- (“to give”). Cognate with Old Turkic [script needed] (ber-, “to give”), Turkish vermek, etc.
#
# []
# Ultimately from Arabic خَبَر‎ (ḵabar).
#
# ['Arabic']
# From Proto-Turkic *yāg.
#
# []
# Morphologically from yanmaq (“to burn”) +‎ -dır
# []
# Ultimately from Proto-Turkic *yāĺ (“young, fresh”).
#
# []
# From Common Turkic *yāša-, a derivation from Proto-Turkic *yāĺ.
#
# []
# From Proto-Turkic *yāy (“summer”).
# []
# From yellə- +‎ -n.
#
# []
# From Proto-Turkic *yē-. Cognate with Old Turkic [script needed] (ye-, “to eat”), Turkish yemek, etc.
#
# []
# Ultimately from Proto-Turkic *yẹr. Cognate with Old Turkic 𐰘𐰼‎ (yer), 𐰘𐰃𐰼‎ (yir).
#
# []
# From Proto-Turkic *uya. Cognate with Chuvash йӑва (jăva).
#
# []
# From Proto-Turkic *adak (“leg”); however, not a regular Kypchak development thereof (which is аяҡ (ayaq)), but apparently a (now extinct) collateral branch with a peculiar semantic shift.
#
# []
# From Proto-Turkic *āń(k) (“moon, month”).
# Cognate with Azerbaijani ay, Turkish, Crimean Tatar ay, Tatar, Kazakh, Kyrgyzай (ay), Southern Altai ай (ay), Uzbek oy, etc.
#
# []
# From Proto-Turkic *ạl- (“to take”).
# Cognate with Old Turkic [script needed] (al-, “to take”); Turkish almak, Yakut ыл (ıl, “to take”), Chuvash ил (il, “to take”), etc.
#
# []
# From Proto-Turkic *āŋla- (“to understand”), from Proto-Turkic *āŋ (“intelligence, mind”).
# Cognate with Old Uyghur [script needed] (aŋla-, “to understand”); Kyrgyz аңдоо (añdoo, “to understand”), Karachay-Balkar ангыларгъа (añılarğa, “to understand”), Uzbek anglamoq (“to understand”), Uyghur ئاڭلىماق‎ (anglimaq, “to listen; to understand”), Turkish anlamak (“to understand”), Azerbaijani anlamaq (“to understand”).
#
# []
# From Proto-Turkic *agrɨ-g (“pain, illness”), an action noun of *agrɨ- (“to ache; be ill”).
# Cognate with
# Karakhanid اَغْرِغْ‎ (aɣrïɣ, “pain”),
# Old Uyghur ՚՚q̈ryq (aɣrïɣ, “pain, illness”),
# Kazakh ауру (awrw, “illness; ill; to be ill”), Kyrgyz оору (ooru), Southern Altai оору (ooru),
# Uzbek ogʻriq (“pain, ilness”),
# Uyghur ئاغرىق‎ (aghriq, “illness”),
# Khakas ағырығ (ağırığ, “illness; ill”),
# Tuvan аарыг (aarıg, “illness, pain”),
# Yakut ыарыы (ıarıı, “pain, disease”),
# Turkish ağrı (“pain, ache”).
#
# []
# From Proto-Turkic *(i)aĺ-a- (“to eat”), from Proto-Turkic *(i)aĺ (“food, meal”).
# Cognate with
# Old Uyghur [script needed] (aša-, “to eat”);
# Kumyk ашамакъ (aşamaq, “to eat”);
# Karachay-Balkar ашаргъа (aşarğa, “to eat”);
# Yakut аһаа (ahaa, “to eat”), etc.
#
# []
# From Common Kypchak *ayaq, from Proto-Turkic *adak (“foot, leg”).
# Compare Old Turkic 𐰑𐰴‎ (adaq, “leg, foot”).
# See also аҙаҡ (aðaq).
#
# []
# From *ayt- (“to say, utter”), from Proto-Turkic *ayɨt- (“to say; ask”), which (as seen in Old Uyghur, Yakut, Chuvash cognates) was originally a causative form of an earlier *ay- (“to say”).
# Compare to
# Tatar әйтү (äytü, “to say”),
# Kazakh айту (aytw, “to say”),
# Kyrgyz айтуу (aytuu, “to say”),
# Crimean Tatar aytmaq (“to say”),
# Uzbek aytmoq (“to say”),
# Uyghur ئېيتماق‎ (ëytmaq, “to say”),
# Kumyk айтмакъ (aytmaq, “to say”),
# dialectal Khakas айт- (ayt-, “to say”), айыт- (ayıt-, “to sing”),
# Turkish ayıtmak (“to say”);
# Old Uyghur [script needed] (ajït-, “to have/make/let sb. say”),
# Yakut ыйыт- (ıyıt-, “to ask”),
# Chuvash ыйт (yjt, “to ask”).
#
# []
# From Proto-Turkic *iāčɨg (“bitter, acid”).
# A palatal parallel development, compare Bashkir асы (asï, “bitter, sour”) from the same archetype.
#
# []
# From Proto-Turkic *bat-gak (“sticky mud, bog”), from *bat- (“to sink, get bogged/stuck in mud”).
# Cognate with
# Kazakh батпақ (batpaq),
# Kyrgyz баткак (batkak),
# Shor патқақ (patqaq),
# Karachay-Balkar батхакъ (batxaq, “clay, mud”),
# Uzbek botqoq,
# Uyghur پاتقاق‎ (patqaq, “sticky mud, bog”),
# Turkmen batga (“swamp, bog”),
# Turkish batak (“swamp, bog”).
#
# []
# From Common Kypchak *baw, from Common Turkic *bāğ (“rope, binder”), from Proto-Turkic *b(i)ā- (“to bind, fasten”).
# Cognate with
# Old Uyghur [script needed] (bağ, “band, binder; bond”);
# Kazakh бау (baw, “cord, binder”),
# Kyrgyz боо (boo, “cord, binder”),
# Southern Altai буу (buu, “cord”),
# Crimean Tatar bav (“knot”),
# Uzbek bogʻ (“cord; bundle”),
# Turkish bağ (“connection”),
# Yakut быа (bıa, “cord, lace”), etc.
#
# ['Common']
# From Proto-Turkic *bīr (“one”).
# Cognate with
# Old Turkic 𐰋𐰃𐰼‎ (bir, “one”), Turkish bir (“one, once”).
#
# []
# From Proto-Turkic *bēr- (“to give”).
# Cognate with Old Turkic -𐰋𐰃𐰼 (bér-, “to give”);  Turkish vermek, Yakut биэр (bier), Chuvash пар (par, “to give”), etc.
#
# []
# Cognate with
# Karakhanid [script needed] (butaq, “branch, twig”);
# Kazakh бұтақ (butaq),
# Kyrgyz бутак (butak),
# Southern Altai будак (budak, “branch, twig”),
# Uzbek butoq (“branch, twig”), etc.
#
# []
# From Proto-Turkic *bōl- (“to become”).
#
# []
# From Persian درست‎ (dorost, “correct”).
#
# []
# From *yebiĺ(č) (“wet”), from Proto-Turkic *yebi- (“to soak, become wet”).
# Cognate with Tatar юеш (yuyeş, “wet”), Karaim йувюш / йӱвӱш / йӱвӱс / йивис (“wet”).
#
# []
# From Common Kypchak *egin "grain crop", from *ekin "cultivated land; crops grown on such land"; from  Proto-Turkic *ek- (“to sow”).
# Cognate with
# Old Uyghur [script needed] (ekin, “arable land, tilled land”);
# Kazakh егін (egin, “grain crops”),
# Kyrgyz эгин (egin, “grain crops”),
# Uzbek ekin (“farm crop”),
# Uyghur ئېكىن‎ (ëkin, “arable land; farm crop”),
# Turkish ekin (“farm crop”).
#
# []
# The only reliable cognate is Kazakh ену (enw, “to enter, go in”). Thus, this is a very peculiar regional feature shared by only these two languages.
# Generally thought to derive from Proto-Turkic *ēn- (“to go down”),.
# However, no adequate explanation has been presented as to how this peculiar semantic transformation ("go down" > "enter") could have taken place, and why only in these two languages but not elsewhere.
#
# []
# From Proto-Turkic *ēr (“man”).
#
# []
# From  Proto-Turkic *ẹĺit- (“to hear”).
# Cognate with Old Turkic 𐱁𐱅‎ (eşit-, “to hear, listen”);  Kazakh есту (estw, “to hear”), Uzbek eshitmoq (“to hear”), Turkish işitmek (“to hear”), Khakas истерге (isterge, “to hear”),Yakut иһит (ihit, “to hear”), Chuvash илтме (iltme, “to hear”).
#
# []
# From Proto-Turkic *yāĺ (“young”).
#
# []
# From Common Turkic *yāša- (“to live”), a derivation of Proto-Turkic *yāĺ.
# Cognate with
# Old Uyghur [script needed] (jaša-, “to live”);
# Kazakh жасау (jasaw, “to live”),
# Kumyk яшамакъ (yaşamaq, “to live”),
# Uzbek yashamoq (“to find”),
# Uyghur ياشىماق‎ (yashimaq, “to live”),
# Southern Altai јажа- (ǰaža-, “to live (up to a certain age)”),
# Khakas чазирға (çazirğa, “to live (up to a certain age)”),
# Turkmen ýaşamak, Turkish yaşamak (“to live”).
#
# []
# From *ūdïkla- (“to sleep”), from  *ūdïk "sleepy", derived from *ūdï- 'to sleep', which in turn derives from *ū "sleep".
# Cognate with
# Kazakh ұйықтау (uyıqtaw), Kumyk юхламакъ (yuxlamaq), Crimean Tatar yuqlamaq, Kyrgyz укта- (ukta-), Southern Altai уйуктаар (uyuktaar), Chulym уқла- (uqla, “to sleep”), Uzbek uxlamoq, Uyghur ئۇخلىماق‎ (uxlimaq),
# Turkmen uklamak (“to sleep”).
#
# []
# From Proto-Turkic *yɨlān (“snake”).
# Cognate with
# Old Turkic [script needed] (jïlan, “snake”);
# Kazakh жылан (jılan), Kyrgyz жылан (cılan),
# Uzbek ilon,
# Uyghur يىلان‎ (yilan),
# Turkish yılan,
# Khakas, Tuvan чылан (çılan, “snake”), etc.
#
# []
# From *kürek (“shovel, spade”), from Proto-Turkic *küre- (“to shovel, rake up”).
# Cognate with
# Kazakh күрек (kürek),
# Kyrgyz күрөк (kürök),
# Karachay-Balkar кюрек (kürek),
# Kumyk кюрек (kürek),
# Uzbek kurak,
# Southern Altai кӱрек (kürek), Shor кӱрек,
# Turkish kürek,
# Crimean Tatar kürek,
# Azerbaijani kürək (“shovel; spade”).
#
# []
# From Common Turkic *kǖč (“force”).
#
# []
# From *küčlüg "strong" (compare Old Turkic 𐰛𐰈𐰲𐰠𐰈𐰏‎ (küčlüg, “strong, mighty”)), from Common Turkic *kǖč (“force”) + +lüg "affix of possession or quality".
# Synchronously, equivalent to көс (kös) +‎ -лө (-lö).
# Cognate with
# Tatar көчле (köçle),
# Crimean Tatar küçlü,
# Uzbek kuchli,
# Uyghur كۈچلۈك‎ (küchlük),
# Turkmen güýçli,
# Turkish güçlü (“strong”), etc.
# See more cognates at көстө (köstö).
#
# ['Common']
# From Proto-Turkic *gǖd- (“to wait; to attend; to respect; to herd”).
# Cognate with
# Old Uyghur [script needed] (küt-, “to wait; to herd”);
# Kazakh күту (kütw, “to wait”),
# Kyrgyz күтүү (kütüü, “to wait; to tend to (cattle)”),
# Uzbek kutmoq (“to wait; to tend to (guests)”),
# Uyghur كۈتمەك‎ (kütmek, “to wait”),
# Yakut күүт- (küüt-, “to wait”) / көһүт- (köhüt-, “to wait”),
# Chuvash кӗт- (kĕt-, “to wait; to herd”).
#
# []
# From  Proto-Turkic *gör- (“to see”).
# Cognate with Old Turkic 𐰚𐰇𐰼𐰇𐰼‎ (körür, “seeing”); Kazakh көру (körw, “to see”), Kyrgyz көрүү (körüü, “to see”), Southern Altai кӧрӧр (körör, “to see”), Uzbek koʻrmoq (“to see”), Khakas кӧрерге (kӧrerge, “to see”), Tuvan көөр (köör, “to see”), Azerbaijani görmək (“to see”), Turkish görmek (“to see”),   Yakut көр (kör, “to see”), Chuvash курма (kurma, “to see”).
#
# []
# From Proto-Turkic *kāpuk (“bark; skin; shell”).
# Cognate with
# Kazakh қабық (qabıq),
# Kyrgyz кабык (kabık), Southern Altai кабык (kabïk),
# Uzbek qobiq (“skin, shell”),
# Turkish kabuk (“shell”),
# Tuvan хавык (xavık, “husk”),
# Chuvash хупӑ (hupă, “bark”),
# etc.
#
# []
# From *qayda "where, at what place", from Proto-Turkic *ka- (“interrogative particle”). -da is a locative case formant.
# Cognate with
# Old Turkic [script needed] (qajda, “where?”),
# Tatar кайда (qayda),
# Ottoman Turkish قانده‎ (kanda),
# Kazakh қайда (qayda),
# Kyrgyz кайда (kayda),
# Crimean Tatar qayda,
# Shor қайда,
# Khakas хайда (xayda),
# Tuvan кайда (kayda),
# etc.
#
# []
# From Proto-Turkic *kadıŕ (“rawhide; belt”).
# Cognate with
# Old Turkic [script needed] (qaðïš, “belt”);
# Kazakh қайыс (qayıs, “rawhide”);
# Kyrgyz кайыш (kayış, “belt”),
# Southern Altai кайыш (kayïš, “belt”)Uzbek qayish (“belt”),
# Khakas хаас (xaas, “belt”),
# Yakut хатыс (xatıs, “leather strap/belt”),
# etc.
#
# []
# From *qara- (“to look”), probably borrowed from Middle Mongolian, from Proto-Mongolic *kara- (“to look”).
# Cognate with Kazakh қарау (qaraw, “to look”), Kyrgyz кара- (kara-, “to look”), Southern Altai кара- (kara-, “to look”), Uzbek qaramoq (“to look”),
# Uyghur قارىماق‎ (qarimaq, “to look”), Khakas хара- (xara-, “to look”).
#
# ['Middle']
# from Common Turkic *xātun (“queen”).
# Compare Old Turkic 𐰴𐱃𐰆𐰣‎ (qatun, “queen”), Karakhanid قاتُونْ‎ (qātūn, “noble woman”), Turkish kadın (“woman”).
#
# ['Common']
# From Proto-Turkic *kol (“upper arm, hand”).
# Cognates include
# Old Uyghur qwl (qol, “arm”);
# Tatar кул (qul, “arm, hand”),
# Kazakh қол (qol, “arm, hand”),
# Uzbek qoʻl (“arm, hand”),
# Turkish kol (“upper arm”),
# Yakut хол (xol, “upper arm”),
# Chuvash хул (hul, “arm; shoulder”).
#
# []
# From Proto-Turkic *kï̄ŕ (“girl”).
# Cognate with
# Old Turkic 𐰶𐰃𐰕‎ (qïz, “girl”);
# Kyrgyz кыз (kız),
# Shor қыс,
# Turkish kız (“girl”), etc.
#
# []
# Cognate with
# Tatar май (may),
# Kazakh май (may),
# Kyrgyz май (may),
# Uyghur ماي‎ (may, “oil, butter, fat, grease”).
#
# []
# Cognate with Tatar матур (matur, “beatiful”) and Chuvash маттур (mattur, “strong, stout; dextrous; brave; beatiful”).
# Ultimately from Proto-Turkic *bagatur (“hero”).
# Irregular nasalization and preservation of a roundness-disharmonic high vowel are sporadically found in inherited vocabulary but could also indicate some sort of reloaning scenario.
# Doublet of батыр (batïr, “hero, brave”).
#
# []
# From Proto-Turkic *büŋüĺ (“corner”).
# Cognate with
# Siberian Tatar мөйәш (möyäš, “corner”),
# Karakalpak мүйеш (“corner”),
# Kazakh мүйiс (müyis, “corner”),
# Karachay-Balkar мюйюш (müyüş, “corner”).
#
# []
# Cognate with
# Kazakh мылтық (mıltıq),
# Nogai мылтык (mıltık),
# Uzbek miltiq,
# Uyghur مىلتىق‎ (miltiq),
# Kyrgyz мылтык (mıltık),
# Southern Altai мылтык (mïltïk),
# Khakas мылтых (mıltıx, “rifle”), etc.
#
# []
# From Persian اوستا‎ (ustâ) / استاد‎ (ostâd). Doublet of остаз (ostaz).
# Note that the first form in Persian may have been reborrowed from a Turkic source.
# Cognate with
# Tatar оста (osta, “master, craftsman”),
# Kazakh ұста (usta, “master; blacksmith”),
# Kyrgyz уста (usta, “master; blacksmith”),
# Uzbek usta (“master, professional”),
# Uyghur ئۇستا‎ (usta, “master, professional”),
# Turkish usta (“master”).
#
# []
# From Common Kypchak üy ("house, home", see the Kypchak cognates below), from Proto-Turkic *eb (“house”).
# Immediately cognate with Tatar өй (öy), Kazakh үй (üy), Kyrgyz үй (üy), Karachay-Balkar юй (üy), Kumyk уьй (üy), Southern Altai ӱй (üy, “home, house”).
#
# []
# From *čet (“edge, border; a location aside/away from sth.; foreign”).
# Cognate with
# Kazakh шет (şet, “edge”),
# Kyrgyz чет (çet, “edge”),
# Uzbek chet (“edge”),
# Uyghur چەت‎ (chet, “edge”),
# Shor чет (“border”), etc.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Cognate with
# Tatar тавыш (tawış),
# Kazakh дауыс (dawıs),
# Karakalpak даўыс (dawıs),
# Karachay-Balkar таууш (tauuş),
# Kyrgyz тоош (tooş),
# Uzbek tovush,
# Uyghur تاۋۇش‎ (tawush),
# Crimean Tatar davuş,
# Khakas табыс (tabıs, “voice, sound”).
#
# []
# From Proto-Turkic *dil (“tongue; language”).
# Cognate with
# Tatar тел (tel),
# Kazakh тіл (til),
# Kyrgyz тил (til),
# Uzbek til,
# Turkish dil (“tongue, language”).
#
# []
# From Proto-Turkic *deri (“skin”).
# Cognate with
# Kazakh терi (teri),
# Karachay-Balkar тери (teri),
# Kumyk тери (teri),
# Kyrgyz тери (teri),
# Uzbek teri,
# Uyghur تېرە‎ (tëre),
# Yakut тирии (tirii),
# Turkmen deri,
# Azerbaijani dəri,
# Turkish deri (“skin”).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# No etymology is known. No cognates are known.
# See also the diminutive тоҡсай (toqsay).
#
# []
# From Proto-Turkic *tur- (“to stand”).
#
# []
# From  Proto-Turkic *tut- (“to hold; keep; catch”).
# Cognate with Old Turkic 𐱃𐰆𐱃‎ (tut-, “to keep, catch, own”);
# Kyrgyz тутуу (tutuu, “to catch”),
# Uzbek tutmoq (“to take, hold, catch”),
# Uyghur تۇتماق‎ (tutmaq, “to hold, grab”),
# Turkish tutmaq (“to catch, keep”),
# Azerbaijani tutmaq (“to catch, keep”),
# Turkmen tutmak (“to hold, keep, catch, hire, fill”),
# Khakas & Shor тударға (tudarğa, “to keep, hold, catch, seize, rule, hold back”),
# Tuvan тудар (tudar, “to hold, catch, grab”), Yakut тут (tut, “to hold, seize, grab, catch”),
# Chuvash тытма (tytma, “to keep, hold”), etc.
#
# []
# From Proto-Turkic *tǖĺ (“dream (seen while sleeping)”).
#
# []
# From a Mongolic source, from Proto-Mongolic *töle- (“to pay”).
# Cognate with
# Old Uyghur [script needed] (tölä-, “to pay”);
# Kazakh төлеу (tölew), Kyrgyz төлөө (tölöö), Uzbek toʻlamoq, Uyghur تۆلىمەك‎‎ (tölimek‎),
# Khakas тӧле- (tӧle-), Tuvan төлээр (töleer, “to pay”).
#
# []
# From *tögerek "round, circle", from
# Proto-Turkic *dög ~ *deg ~ *dog (“round, circle”).
# Compare with
# Tatar түгәрәк (tügäräq),
# Kazakh төңірек (töñirek),
# Kyrgyz төгөрөк (tögörök),
# Uzbek toʻgarak (“circle”),
# Uyghur تۈگۈرەك‎ (tügürek, “circle”),
# Yakut төгүрүк (tögürük, “round”).
# The noun sense of "hobby group" is semantic loan from  Russian кружо́к (kružók).
#
# []
# From Proto-Turkic *dɨrŋa-k (“fingernail, claw”).
# Cognate with
# Old Turkic 𐱃𐰃𐰺𐰭𐰴‎ (tïrŋaq, “fingernail, claw”);
# Kazakh тырнақ (tırnaq),
# Kyrgyz тырмак (tırmak),
# Uzbek tirnoq,
# Uyghur تىرناق‎ (tirnaq),
# Crimean Tatar tırnaq,
# Turkish tırnak,
# Turkmen dyrnak,
# Tuvan дыргак (dırgak),
# Yakut тыҥырах (tıŋırax, “fingernail, claw”).
#
# []
# From Proto-Turkic *o-l (“that”). Compare Old Anatolian Turkish 𐰆𐰞‎ (ol) and Karakhanid اُلْ‎ (ol).
#
# []
# From Proto-Turkic *oltur- (“sit”).
#
# []
# From Proto-Turkic *sā-n (“number”), from Proto-Turkic *sā- (“to count”).
# Cognate with:
# Old Uyghur s՚n (san, “number”).
#
# []
# From Proto-Turkic *sogɨ-k (“cold”).
# Cognate with
# Old Turkic [script needed] (soγïq), Old Turkic [script needed] (soγuq, “cold”),
# Kazakh суық (swıq), Kyrgyz суук (suuk), Uyghur سوغۇق‎ (soghuq)/Uyghur соғуқ (soghuq), Uzbek sovuq, Tuvan соок (sook), Turkmen sowuk, Turkish soğuk (“cold”), etc.
#
# []
# From Persian چشمه‎ (češme, “spring, source”).
#
# []
# From Proto-Turkic *īĺč (“work, deed”). Compare Turkish iş.
#
# []
# From the noun эш.
#
# []
# Probably a derivation of Proto-Turkic *yara- (“be good enough, be sufficient, be successful”), appended with the causative suffix -t.
# Cognate with
# Tatar ярату (yaratu, “to love”),
# Kazakh жарату (jaratw, “to like, approve of”),
# Kyrgyz жаратуу (caratuu, “to like, approve of”),
# Uyghur ياراتماق‎ (yaratmaq, “to love, sypathize”).
#
# []
# From Proto-Slavic *(j)edinъ, ultimately from Proto-Indo-European *óynos (“one, single”).
#
# []
# From Proto-Slavic *bojàti.
#
# []
# From Proto-Slavic *ǫgъlъ. Cognate with Russian у́гол (úgol).
#
# []
# From Proto-Slavic *vęzati.
#
# []
# From Proto-Slavic *grǫdь.
#
# []
# Unknown, cognate with Russian гуля́ть (guljátʹ), Ukrainian гуля́ти (huljáty).
#
# []
# From Proto-Slavic *dȍmъ (“house; home”).
#
# []
# A borrowing from Old Church Slavonic дрѣво (drěvo); ultimately from Proto-Slavic *dervo, from Proto-Indo-European *dóru. Doublet of дзе́рава (dzjérava), the inherited East Slavic form.
#
# ['Old']
# From Proto-Slavic *žiti (compare Russian жить (žitʹ), Ukrainian жи́ти (žýty), Old Church Slavonic жити (žiti)), from Proto-Indo-European *gʷeih₃w- (“to live”). Cognate to Lithuanian gyventi, Sanskrit जीवति (jīvati), Latin vīvō.
#
# []
# Cognates include Russian звони́ть (zvonítʹ), Ukrainian дзвони́ти (dzvonýty) and Polish dzwonić.
#
# []
# From Old East Slavic коньць (konĭcĭ, “end; edge, border”), from Proto-Slavic *konьcь (“end”).
#
# []
# From ко́лькі (kólʹki) +‎ -асць (-ascʹ).
#
# []
# From Proto-Slavic *listъ (“leaf”). Cognate with Russian лист (list).
#
# []
# From лік (lik).
#
# []
# From Old East Slavic мѣстьце (městĭce), мѣстце (městce), from Proto-Slavic *městьce, from *město (“place, town”) +‎ *-ьce. Equivalent to ме́ста (mjésta) +‎ -ца (-ca).
# Cognate with Ukrainian мі́сце (mísce), Polish miejsce.
#
# []
# From Proto-Slavic *měsęcь, from Proto-Indo-European *mḗh₁n̥s.
#
# []
# From Proto-Slavic *noga, from Proto-Indo-European *h₃nogʰ-.
#
# []
# Cognate with Russian подня́ть (podnjátʹ).
#
# []
# Cognate with Russian поки́нуть (pokínutʹ).
#
# []
# From Old East Slavic пальць (palĭcĭ), from Proto-Slavic *palьcь (“thumb, finger”).
#
# []
# па- (pa-) +‎ чуць (čucʹ)
# []
# Cognate with Russian по́лдень (póldenʹ).
#
# []
# From Polish skóra, from Proto-Slavic *skora. Cognate with Russian скора́ (skorá). Doublet of шку́ра (škúra) and скі́ра (skíra).
#
# []
# From Proto-Slavic *sъ̀nъ, from Proto-Indo-European *supnós.
#
# []
# From Proto-Slavic *starъ.
#
# []
# From Proto-Slavic *tьnъkъ. Cognate with Russian то́нкий (tónkij).
#
# []
# From у- (u-) +‎ стаць (stacʹ). Cognates include Ukrainian уста́ти (ustáty), Russian встать (vstatʹ) and Polish wstać.
#
# []
# From Proto-Slavic *tęgnǫti. Cognate with Ukrainian тягну́ти (tjahnúty).
#
# []
# From Proto-Slavic *čakati, *čekati.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.). Cognate with Ukrainian шту́рхати (štúrxaty).
#
# []
# Borrowed from Sanskrit अग्नि (agni), from Proto-Indo-Aryan *agní, from Proto-Indo-Iranian *Hagnis, from Proto-Indo-European *h₁n̥gʷnis
# ['Sanskrit']
# Locative of এখান (ekhan)
# []
# Locative of ওখান (okhan)
# []
# Borrowed from Sanskrit खाद्य (khādya).
#
# ['Sanskrit']
# Akin to Hindi खेलना (khelnā)
# []
# From Sanskrit গল (gala). Cognate to Hindi गला (galā).
# []
# Compare to Hindustani देखना (dekhnā) / دیکھنا‎ (dekhnā)
# []
# Compare to Hindustani पढ़ना (paṛhnā) / پڑھنا‎ (paṛhnā).
#
# []
# Compare to Assamese বোলা (büla), Hindi बोलना (bolnā), Marathi बोलणें (bolṇẽ) and Punjabi ਬੋਲਣਾ (bolṇā).
#
# []
# Cognate with Assamese শুনা (xuna)
# []
# From Proto-Celtic *amstera (“time, moment”). Cognate with Welsh amser, Irish aimsir.
#
# []
# Borrowed from Latin discō (“I learn”). Cognate with Welsh dysgu and Cornish dyski, from the same origin.
#
# ['Latin']
# Infinitive from kavout (to find), all other forms from the verb bezañ (to be). Cognate with Cornish kavos and y'm beus.
#
# []
# Verbal noun from Old Breton oper, from Latin opera (cf. Cornish ober, Welsh gober). Inflected forms in gr- from an earlier gwr-, itself from Proto-Celtic *wregeti, cognate with Welsh gwneud (older forms with initial gwr-) and Cornish gwul (all forms in gwr-).
#
# ['Old', 'Latin']
# Borrowed from Latin saccus. Cognate with Welsh sach.
#
# ['Latin']
# From Proto-Brythonic *ti, from Proto-Celtic *tū, from Proto-Indo-European *túh₂. Cognate to Welsh ti.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From Proto-Slavic *biti.
#
# []
# From Proto-Slavic *bordà, from Proto-Indo-European *bʰardʰéh₂.
#
# []
# From Proto-Slavic *bergъ.
#
# []
# From Proto-Slavic *běgati (“to flee, run”).
#
# []
# From Proto-Slavic *vorta n pl, reanalyzed as a feminine singular.
#
# []
# From Proto-Slavic *vermę.
#
# []
# Cognate with Slovene vrv, Serbo-Croatian врвца/vrvca and врпца/vrpca, Russian верёвка (verjóvka).
#
# []
# връ́з(вам) (vrǎ́z(vam)) +‎ -ка (-ka)
# []
# From Proto-Slavic *vьrxъ.
#
# []
# From Proto-Slavic *vьlna (“wool”), from Proto-Indo-European *h₂wĺ̥h₁neh₂ (“wool”).
#
# []
# From Proto-Slavic *govoriti, from Proto-Indo-European *gow(H)- (“to call, cry”).
#
# []
# Diminutive of ду́па (dúpa, “gap, indention”) (mostly obsolete) +‎ -ка (-ka).
#
# []
# From Proto-Slavic *drъvo, from Proto-Indo-European *dóru.
#
# []
# From Proto-Slavic *(j)ęzykъ, from Proto-Indo-European *dn̥ǵʰwéh₂s.
#
# []
# Deverbial noun from жела́я (želája, “to wish, to desire”) +‎ -ние (-nie), from Proto-Slavic *želati.
#
# []
# From Proto-Slavic *živěti.
#
# []
# From Proto-Slavic *zemľa, from Proto-Balto-Slavic *źemē, from Proto-Indo-European *dʰéǵʰōm.
#
# []
# From Proto-Slavic *jьti.
#
# []
# From Proto-Slavic *kalъ.
#
# []
# From Proto-Slavic *klonъ.
#
# []
# From Proto-Slavic *koža.
#
# []
# From Proto-Slavic *kora, from Proto-Indo-European *ker-.
#
# []
# From Proto-Slavic *krajь.
#
# []
# From Proto-Slavic *korkъ (“limb, span”).
#
# []
# From Proto-Slavic *kǫsъ. Cognate with Russian кус (kus) and кусок (kusok), Slovene kos, Serbo-Croatian кус, kus, Slovak kus. Non-Slavic cognates include Sanskrit खादति (khādati, “he chews”), Persian خاییدن‎ (xāyīdan, “to chew”).
#
# []
# From Proto-Slavic *lopata. Morphologically formed from лоп- (lop-, “sheet, spade”) +‎ -ата (-ata).
#
# []
# From Proto-Slavic *lošь.
#
# []
# From Proto-Slavic *měsęcь, from Proto-Indo-European *mḗh₁n̥s.
#
# []
# Inherited from Proto-Slavic *moťь.
#
# []
# From Proto-Slavic *město.
#
# []
# From Proto-Slavic *noga (originally: claw), from Proto-Indo-European *h₃nogʰ-.
#
# []
# From Proto-Slavic *nogъtь, ultimately from Proto-Indo-European *h₃nogʰ-.
#
# []
# Formed as об- (ob-) +‎ върна (vǎrna, “to return”).
#
# []
# о- (o-) +‎ пи́там (pítam)
# []
# From Proto-Slavic *paziti.
#
# []
# From Proto-Slavic *podъ.
#
# []
# From Proto-Slavic *prǫtъ.
#
# []
# From Proto-Slavic *orbota, from *orbъ (“slave”) + *-ota.
#
# []
# Deverbial noun from разстоя́ (razstojá, “to be at a distance”) +‎ -ние (-nie), from Proto-Slavic *orzstojati.
#
# []
# From Proto-Slavic *rǫka, from Proto-Balto-Slavic *ránkāˀ.
#
# []
# с- (s-) +‎ въ́рша (vǎ́rša)
# []
# From Proto-Slavic *sila.
#
# []
# From Proto-Slavic *silьnъ.
#
# []
# From Proto-Slavic *synъ, from Proto-Balto-Slavic *sū́ˀnus, from Proto-Indo-European *suHnús.
#
# []
# с- (s-) +‎ кри́я (kríja)
# []
# From Old Church Slavonic стати (stati), from Proto-Slavic *stati (“to stand, become”).
#
# []
# From Proto-Slavic *starъ.
#
# []
# From Proto-Slavic *stornà (“side, land”); morphologically from стор (stor, “spread, extension”) (obsolete, archaic) +‎ -на (-na).
#
# []
# From Proto-Slavic *sъ̀nъ, from Proto-Indo-European *supnós.
#
# []
# From Proto-Slavic *tvьrdъ.
#
# []
# From Proto-Slavic *tъgъda (“then”) + -ва (-va).
#
# []
# From Proto-Slavic *tьnъkъ. Akin to English thin, tight.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Probably of Iranian origin (compare Persian خوب‎ (“good”)), formally from Proto-Slavic *xubъ + -ав (-av). Cognate with Macedonian убав (ubav).
#
# []
# From Proto-Slavic *čьrta.
#
# []
# From Proto-Slavic *ǫgъlъ, from Proto-Indo-European *h₂engulos (“joint?”), from *h₂eng- (“corner”).
#
# []
# Uncertain. Possibly of pre-Roman origin, or of Gothic origin. Compare Spanish amagar (“to threaten”) and  Portuguese esmagar.
#
# []
# Borrowed from French attraper.
# ['French']
# From Old Occitan, from Medieval Latin, Late Latin bursa, from Ancient Greek βύρσα (búrsa). Doublet of borsa.
#
# ['Medieval', 'Ancient']
# From camí +‎ -ar.
#
# []
# From Latin corrigia, attested from 1271.
# []
# Possibly from Latin de ex pressum, or more likely from Old Catalan despuix, despuis, depuis (itself from Latin de post) + aprés.
# ['Latin', 'Old', 'Latin']
# From Old Occitan [Term?] (compare Occitan ensenhar), from Vulgar Latin insignāre, present active infinitive of insignō (compare French enseigner, Spanish enseñar), from Latin signō.
#
# ['Vulgar', 'Latin']
# From Old Occitan, from Medieval Latin friscus, frescus, of Germanic origin, from Proto-Germanic *friskaz. More at English fresh.
#
# ['Medieval']
# From Italian pantano, attested from the 14th century.
# []
# From Old Occitan [Term?], from Vulgar Latin *passāre, from Latin passum, supine of pando (“I stretch, I spread out”). Compare Occitan passar, French passer, Spanish pasar, Italian passare.
#
# ['Vulgar', 'Latin']
# From Old Occitan, from Vulgar Latin *pendicāre, from Latin pendēre, present active infinitive of pendeō, from Proto-Italic *pendēō, from Proto-Indo-European *(s)pend- (“to pull; to spin”)
# ['Vulgar', 'Latin']
# From Old Occitan, from Vulgar Latin *pīccāre, itself a derivative of Latin pīcus or of onomatopoetic origin.
#
# ['Vulgar']
# From a variant of Old Occitan [Term?], from Late Latin pausāre, present active infinitive of pausō, influenced in meaning by Latin pōnō. Compare French poser, Occitan pausar, Spanish posar, Portuguese pousar, Italian posare.
#
# ['Late']
# Borrowed from Latin praeparāre, present active infinitive of praeparō (“I prepare”).
#
# ['Latin']
# From Old Occitan, from Latin *podiāre, from Latin podium. Compare Occitan pujar, Aragonese puyar, Portuguese pojar, Italian poggiare; cf. also French appuyer, Spanish apoyar, Italian appoggiare, from a Vulgar Latin *appodiāre.
#
# ['Latin']
# From sacsar +‎ -ejar.
#
# []
# From Old Occitan (compare Occitan sortir), from Latin sortīrī (“to select”) (present active infinitive of sortior), probably influenced by surrectus (through a Vulgar Latin form *surctus and its derivatives, possibly through a verb *surrectīre, surctīre; cf. also Old Catalan surt, surta).
#
# ['Latin']
# From Old Occitan, from Late Latin taleare or taliāre, present active infinitive of taliō, from Latin talea.
#
# ['Late', 'Latin']
# From Medieval Latin, from Vulgar Latin *tirō, tirāre, from Proto-Germanic *teraną (“to tear, tear away, rip or snatch off, pull violently, tug”) (through Gothic *𐍄𐌹𐍂𐌰𐌽 (*tiran)), from Proto-Indo-European *der- (“to tear, tear apart”). Alternatively Late Latin *martyrāre, possibly with influence from Latin trahō. Compare French tirer, Italian tirare.
#
# ['Vulgar', 'Latin']
# From Old Occitan, from Vulgar Latin *ungla, syncopated form of Latin ungula, from unguis, ultimately from Proto-Indo-European *h₃negʰ-.
#
# ['Vulgar']
# From Old Czech chot, from Proto-Slavic *chotь. Related to chtít.
#
# []
# jíst +‎ -dlo
# []
# From o- +‎ hnout.
#
# []
# při- +‎ vázat
# []
# From s- +‎ chovat.
#
# []
# From s- +‎ pojit
# []
# Compare Slovak vetva and Russian ветвь (vetvʹ).
#
# []
# From Proto-Nakh *butt.
#
# []
# From Proto-Nakh *dāli.
#
# []
# From Proto-Nakh *kōḳ.
#
# []
# From Proto-Nakh *qēra.
#
# []
# From Proto-Nakh *lātte.
#
# []
# From Proto-Nakh *moṭṭ.
#
# []
# From Proto-Nakh *pχā. Cognate with Ingush пхьан (pḥan, “hornbeam”). Associated with several weapon names, because they were made of hornbeam: Chechen пха (pχa, “arrow”), пха, пхьа (pχa, pḥa, “shield”), пхердукъ (pχerduq̇, “spear”).
#
# []
# From сан (san, “my, mine”); related to сирла (sirla, “light, bright, clear”) and серло (serlo, “light, brightness, illumination”).
#
# []
# Cognate with Ingush ха (χa). Related to Georgian ხანი (xani). This etymology is incomplete. You can help Wiktionary by elaborating on the origins of this term.
# []
# From Proto-Nakh *xi.
#
# []
# From Proto-Nakh *cħa.
#
# []
# From Proto-Nakh *c̣e (“name”).
#
# []
# From Proto-Nakh *jobq̇.
#
# []
# Borrowed from Russian обед (obed).
#
# ['Russian']
# Related to Tatar апа (apa), from Old Turkic apa.
#
# ['Old']
# Compare Tatar ут (ut).
#
# []
# From Proto-Turkic *kȫk.
#
# []
# From Proto-Turkic *gīr- (“to enter”). Cognate with Old Turkic 𐰚𐰃𐰼‎ (kir- /kir²/), Turkish girmek, Azerbaijani girmək etc.
#
# []
# From Proto-Turkic *gül. Cognate with Turkish and Azerbaijani -gil (“someone's home or family”), Yakut күүлэ (küüle, “entrance hall”).
#
# []
# From Proto-Turkic *buŕ- / *boŕ- (“to damage, destroy”). Cognate with Azerbaijani pozmaq, Bashkir боҙоу (boðou).
#
# []
# Related to Turkish bulut and Yakut пылыт (pılıt), from Proto-Turkic *bulït, .
#
# []
# From Proto-Turkic *biarŋak.
#
# []
# From Proto-Turkic *yāŕ. Cognate with Turkish yaz (“summer”).
#
# []
# Historically from тăв (tăv) (< тав (taw) < тау (tau)), from Proto-Turkic *tāg.
#
# []
# From Proto-Turkic *kāŕ, compare Turkish kaz.
#
# []
# From Proto-Turkic *dɨl.
#
# []
# From Proto-Turkic *dik- (“vertical; to to plant vertically”).
# Compare Azerbaijani dikmək (“to bury”) dik (“upright, vertical”), tikmək (“to sew”); Turkish dikmek (“to sew”), Kumyk тикмек (tikmek, “to sew; to build”) Kazakh тігу (tigw).
#
# []
# Related to Turkish diş.
#
# []
# From Proto-Chukotko-Kamchatkan *ðəlɣə (“finger”). Compare also Koryak йәлгәлӈән, Alutor тылгылӈын and Itelmen луфԓич.
#
# []
# Cognate with Japhug amdzɯ (Zhang, Jacques, and Lai, 2019).
#
# []
# Simplified from 點 (黑 → 灬). Note that 黑 changed from being on the left to being 灬, underneath. Compare 黙 (from 默), which retains the 里, and 黒, which is the simplification in isolation.
# Current form is graphically 占 + 灬.
#
# []
# From Proto-Sino-Tibetan *m-kul (“twenty; all”); cognate with 昆 (OC *kuːn, “swarming”), Tibetan ཀུན (kun, “all”), Burmese အကုန် (a.kun, “all”) (Benedict, 1972; STEDT).
#
# []
# From Proto-Sino-Tibetan *m/g-(r)wa-ŋ/k/t (“horn; angle; corner”) (STEDT). Cognate with Tibetan རྭ (rwa, “horn”), Garo grong (“horn”), Jingpho nrung (n̩³¹ ʒuŋ³³, “horn”), Chepang रोङः (roŋʔ, “horn”), 觡 (OC *kraːɡ, “antler”). The Tibeto-Burman *-ŋ final variant is reflected in 觥 (OC *kʷraːŋ, “drinking vessel made from animal horn”) (Schuessler, 2007). Possibly also related to 鹿 (OC *b·roːɡ, “deer”) (Sagart, 1999).
# A derivative is 餃 (“stuffed dumpling”), named for its horn-like shape (Norman, 1988).
# It is probably unrelated with Proto-Indo-European *ḱr̥h₂nós (“horn”) ( < *ḱerh₂- (“horn”)) and Proto-Semitic *ḳarn- (“horn”) despite the phonological and semantic resemblance between the three.
#
# []
# Proto-Celtic *bawā. Compare French boue (“mud”), from Gaulish *bauā.
#
# []
# From berw (“boiling”) +‎ -i.
#
# []
# From Middle Welsh bwrt, from Old English bord (compare Irish bord); doublet of bord.
#
# ['Old']
# From Proto-Brythonic *catarno, from Proto-Celtic *katus (“battle”). See cad.
#
# []
# From cau +‎ -ad.
#
# []
# From cangau, plural of cainc (“branch”) (from Proto-Celtic *kankā),  +‎ -en (singulative suffix).
# []
# From casgl (“collection”) +‎ -u.
#
# []
# Cognate with Cornish gwari and Breton c'hoari.
#
# []
# Cognate with Cornish kelmi, Breton koulmañ.
#
# []
# From Proto-Brythonic *klüwid, from Proto-Celtic *klusīti, from Proto-Indo-European *ḱlew-.
#
# []
# Clipping of cyfodi, from cyf- +‎ odi.
#
# []
# From Proto-Celtic *koudeti, from Proto-Indo-European *(s)kewdʰ- (“to cover, wrap, encase”),  +‎ -io (forming verbnouns). Cognate with Cornish cuthe, Breton cuzaff, English hide, Latin custōs, Ancient Greek κεύθω (keúthō, “to conceal”), Sanskrit कुहरम् (kuharam, “cave”).
#
# []
# From cwymp.
#
# []
# From cyf- +‎ rhif.
#
# []
# From Proto-Brythonic *dalg-, from Proto-Indo-European *delgʰ-. Cognate with Latin indulgeo.
# []
# Contraction of older deau (“right; south”), from Proto-Celtic *dexsos (“right”). Cognate with Cornish dyhow, Breton dehou, Irish deas, Scottish Gaelic deas, Manx jiass.
# The sense "south" comes from the fact that the south is on the right-hand side of a person facing east.
# []
# Borrowed from Latin discō (“I learn”). Cognate to Breton deskiñ and Cornish dyski, from the same origin.
#
# ['Latin']
# Borrowed from Old English ford
# ['Old']
# Ultimately from Proto-Indo-European *ǵʰeh₁- (“to leave behind, abandon”).
# []
# From gorchudd +‎ -io.
#
# []
# From Old Welsh guor (“over”) +‎ phenn (“head”) (see penn).
# Cognate with Cornish gorfedna, Breton gourfennañ.
#
# []
# From Proto-Celtic *u̯o-stutā (see go-), from Proto-Indo-European *steh₂-.
# []
# From Proto-Celtic *grendsmu, from Proto-Indo-European *gʰredʰ-. Cognate with Latin gradus (“step”).
#
# []
# The variant gwddwg is cognate with Old Breton guodoc (Middle Breton gouzouc, Breton gouzoug, goûg), but it is difficult to explain the alternation between -wg, -w, and -f. The oldest form of the word cited in Geiriadur Prifysgol Cymru is the Middle Welsh plural form gedueu (13th century; = modern gyddfau), while the soft mutation forms wðwc, wddf, and wddw are all attested in the 14th century, indicating that the alternation is very old.
#
# []
# Back-formation from gwneuthur, from Middle Welsh gwneuthur, altered from *gwreithur with -n- from gwnïo (“to sew”), from Proto-Celtic *wregeti (compare Cornish gwra (“he does, makes”), Breton gra (“he does, makes”), Old Irish fairged (“they made”)), from Proto-Indo-European *werǵ- (compare English work). Middle Welsh preserved the -r- in the preterite: gwreith (“I did, made”), goruc (“he did, made”).
#
# ['Middle']
# gwth +‎ -io
# []
# From gyr (“drive, thrust; flock, drove”) +‎ -u.
#
# []
# Cognate with Breton moan, Cornish moon.
#
# []
# Ultimately from Proto-Indo-European *med- (“measure; advise”).This etymology is incomplete. You can help Wiktionary by elaborating on the origins of this term.
# []
# Suppletive verb; verbal noun from Middle Welsh mynet, from Proto-Brythonic *moned (compare Cornish mones, Breton mont), verbal noun of Proto-Celtic *monītor (compare Middle Irish muinithir (“goes around”)), from Proto-Indo-European *menH- (compare Umbrian menes (“will come”), Lithuanian mìnti (“to trample, scutch”)). Indicative forms from Proto-Celtic *ageti (“to drive”) (compare Old Irish aigid), from Proto-Indo-European *h₂eǵ- (compare Latin agō). The forms in el- are from Proto-Celtic *ɸel- (“to approach, drive”), from Proto-Indo-European *pelh₂- (compare Latin pellō (“strike, drive”), Epic Greek πίλναμαι (pílnamai, “approach”).
#
# ['Middle']
# From pell (“far (away), distant, remote”) +‎ -ter.
#
# []
# From Latin probō (“to test”).
#
# []
# pwdr +‎ -u. Cognate with Cornish pedri.
#
# []
# From rhuthr (“rush”, noun) +‎ -o, ultimately from Proto-Indo-European *h₃rew- (“to hurry”). Cognate with Middle Irish rúatharaigid (“makes a rush or onset”), from rúathar, rúathur m (“onrush, onset, attack”).
# []
# From sain +‎ -io.
#
# []
# sych (“dry”) +‎ -u.
#
# []
# Ultimately from Proto-Indo-European *terh₁- (“to rub, turn; pierce”).
# []
# According to Matasovic, from a non-Indo-European language, but Pokorny suggests Proto-Indo-European *terkʷ- (“to twist, spin”).  Cognate with Cornish terri, Breton torriñ.
#
# []
# From tro +‎ -i.
#
# []
# Perhaps ultimately from Proto-Indo-European *ten- (“stretch, extend”).
# []
# From ym- +‎ gadael (“leave”)
# []
# From ym- +‎ dangos.
#
# []
# See ym-. Cognate with Irish imeall.
# []
# From ysgub +‎ -o.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From Old Norse annarr, from Proto-Germanic *anþeraz (“second, other”).
#
# []
# From Old Danish athræ, Old Norse ædr, from Proto-Germanic *ēþrǭ (“vein”). Related to German Ader.
#
# []
# ...
#
# ['Middle']
# Old Norse stikka, from Proto-Germanic *stikkô. Compare Icelandic stika, English stick.
#
# []
# From அ (a, “there, that”, pronominal base) +‎ பொழுது (poḻutu, “time”). see Proto-Dravidian *a-. (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Cognate with Tulu ಕಟ್ಟ್ (kaṭṭ), Telugu కట్టు (kaṭṭu) (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Cognate with Kannada ಕತ್ತು (kattu), Malayalam കഴുത്ത് (kaḻuttŭ)(This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Cognate with Telugu కాలు (kālu), Malayalam കാല് (kālŭ), Kannada ಕಾಲು (kālu), Tulu ಕಾರ್ (kār).
#
# []
# From Sanskrit गुहा (guhā)
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Cognate with Malayalam കേൾ (kēḷ).
#
# []
# Cognate with Malayalam കൊമ്പ് (kompŭ), Telugu కొమ్ము (kommu), Kannada ಕೊಂಬು (kombu)
# []
# From செய் (cey) +‎ -தி (-ti). Cognate with Telugu చెయిదము (ceyidamu).
#
# []
# Cognate with Telugu చేరు (cēru), Kannada ಸೇರು (sēru).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Cognate with Telugu తూగు (tūgu), Telugu తూకొను (tūkonu), Malayalam തൂക്കുക (tūkkuka).
#
# []
# Cognate with Kannada ಹಿಡಿ (hiḍi), Malayalam പിടി (piṭi), Telugu పిడి (piḍi).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From மறைத்தல் (maṟaittal, “to conceal”).
#
# []
# From Proto-Dravidian *vīṭu. Cognate with Kannada ಬೀಡು (bīḍu, “house”), Malayalam വീട് (vīṭŭ).
#
# []
# From Proto-Turkic *ïgač.
#
# []
# From Proto-Turkic *āń(k) (“moon, month”). Compare Bashkir ай (ay, “moon”).
#
# []
# From Proto-Turkic *bōl- (“to become”).
#
# []
# Related to Turkish er.
#
# []
# From Proto-Turkic *kāpuk (“bark; skin; shell”).
#
# []
# From Proto-Turkic *kara (“black”)
# []
# From Proto-Turkic *kȫk.
#
# []
# From Proto-Turkic *okï-.
#
# []
# From Old Turkic ös-.
#
# []
# Borrowed from Persian هوا‎ (havâ) or Arabic هَوَاء‎ (hawāʾ).
#
# ['Persian']
# From Proto-Turkic *īĺč (“work, deed”). Compare Turkish iş.
#
# []
# From the noun эш.
#
# []
# From Proto-Turkic *yāĺ (“young”).
#
# []
# From Sanskrit आरम्भ (ārambha, “beginning”) +‎ -ఇంచు (-iñcu).
#
# []
# From Sanskrit आहार (āhāra, “taking, fetching; employing, use; taking food”)  +‎ -ము (-mu).
#
# []
# Cognate with Tamil கட்டு (kaṭṭu, “tie, bandage, knot”)
# []
# కాపు (kāpu) +‎ ఆడు (āḍu)
#
# []
# కోరు (kōru) +‎ ఇక (ika)
#
# []
# From గీయు (gīyu, “to draw a line”)
# []
# Borrowed from Sanskrit गुहा (guhā).
#
# ['Sanskrit']
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# చెల్లు (cellu) +‎ -ఇంచు (-iñcu)
# []
# From చేయు (cēyu, “to do”)
# []
# From Sanskrit तीर (tīra, “beach, shore, bank”) +‎ -ము (-mu).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# పట్టు (paṭṭu) +‎ కొను (konu)
# []
# From Sanskrit प्रकाश (prakāśa)  +‎ -ఇంచు (-iñcu)
# []
# From Sanskrit प्रवेश (praveśa, “entering, entrance”)  +‎ -ఇంచు (-iñcu)
# []
# From Sanskrit भय (bhaya, “fear”) + Telugu పడు (paḍu)
# []
# From మారు (māru)
# []
# లెక్క (lekka) +‎ పెట్టు (peṭṭu)
# []
# వెలుగు (velugu) +‎ -ఇంచు (-iñcu)
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Cognate with Old Turkic [script needed] (aldā-).
# []
# From Old Turkic baġla- , from bağ.
#
# []
# From Old Turkic bat-, from Proto-Turkic *bat-.
#
# []
# From Old Turkic bekle-.
#
# []
# From Old Turkic büt-, from Proto-Turkic.
#
# []
# From Old Turkic boz-, buz-, from Proto-Turkic *buŕ- (“to damage, destroy”), *boŕ- (“to damage, destroy”).
#
# []
# From Old Turkic çal-‎ (çal-), from Proto-Turkic.
#
# []
# From Old Turkic tal, from Proto-Turkic *tāl, *dal.
#
# []
# From Old Turkic, from Proto-Turkic.
#
# []
# From Old Turkic tur-, from Proto-Turkic *dur- (“to stand”).
#
# []
# From Old Turkic tuy-, from Proto-Turkic *duj- (“to perceive (by ears or nose), notice”).
#
# []
# From Proto-Turkic *in (“lair, burrow”). Cognate with Kazakh ін (in).
#
# []
# From Ottoman Turkish اینچه‎ (ince/inçe), from Proto-Turkic *yiŋč-ge (“thin”).
#
# []
# From Old Turkic it-, from Proto-Turkic *it- (“to push, hit”).
#
# []
# From Ottoman Turkish and Old Anatolian Turkish قاپو‎ (qapu). Ultimately a derivation from Proto-Turkic *kap- (“to close, cover”). Cognate with Old Turkic 𐰴𐰯𐰍‎ (kapıg), Azerbaijani qapı, etc.
#
# []
# From Old Turkic kogış, from Proto-Turkic *K(i)adɨ-.
#
# []
# From Ottoman Turkish قرمق‎, from Proto-Turkic *kïr-.
#
# []
# From Old Turkic kıdıg, from Proto-Turkic *Kɨd-.
#
# []
# From Ottoman Turkish قونشمق‎.
# Surface etymology kon +‎ -uş + -mak. Literally, "to settle mutually".
#
# []
# From Proto-Turkic. Cognate with Azerbaijani qorxmaq, Kazakh қорқу (qorqw), Uzbek qoʻrqmoq, Chuvash хӑра (hăra).
#
# []
# Cognate with Azerbaijani qorumaq (“to protect”), Old Turkic 𐰸𐰆𐰺‎ (korï-, “to protect”), Uzbek qoʻrimoq (“to protect”).
#
# []
# From Old Turkic köti, from Proto-Turkic.
#
# []
# From Old Turkic kod-, from Proto-Turkic.
#
# []
# From Old Turkic koñ, from Proto-Turkic; cognate with Azerbaijani qoyun, Turkmen goýun, Kazakh қой (qoy), Uzbek qo'y. Related to written Mongolian ᠬᠣᠨᠢᠨ (qonin, “sheep”), Mongolian хонь (honʹ, “sheep”), Buryat хонин (xonin, “sheep”) and Kalmyk хөн (xön, “sheep”), but the nature of relationship is unclear; the Mongolic terms may be borrowed from Turkic. Pedersen derived all of these forms from Old Armenian խոյ (xoy), but in Doerfer's opinion this is phonetically impossible. Ačaṙyan too regards the resemblance to Old Armenian խոյ (xoy) as accidental.
#
# ['Old']
# From Ottoman Turkish او‎ (o).  Merger of Old Anatolian Turkish ol‎ and an‎ (“she, he, that, it”), from Old Turkic 𐰆𐰞‎ (ol) and [script needed] (an), respectively; both from Proto-Turkic. Cognate with Karakhanid اُلْ‎ (“he, she, it; that”) and Chinese 兀 (wù, “that”).
#
# ['Old']
# From Old Turkic [script needed] (öte-), from Proto-Turkic *ȫte-.
#
# []
# From Ottoman Turkish پارلامق‎.
#
# []
# pis (“dirty”) +‎ -lik
# []
# From Proto-Turkic *saba- (“to beat, hit, fight”). Cognate with Azerbaijani savaş (“war”).
#
# []
# From Proto-Turkic *ses. Cognate with Crimean Tatar, Gagauz, Turkmen ses, Azerbaijani səs.
#
# []
# From Old Turkic sipir-, süpür-, from Proto-Turkic. Cognate with Azerbaijani süpürmək, Chuvash шӑпӑр (šăpăr, “broom”)
# []
# Cognate with Old Turkic [script needed] (sürüg).
#
# []
# From Old Turkic titre-  ("to shake due to fear, anger or cold"), from titiz ("acrid or angry").
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From Old Turkic.
#
# []
# From Old Turkic yalıŋuz, from yalŋus, from yalıŋ ("naked") (compare yalın), from yalın- ("to undress oneself"), from Proto-Turkic *yalïŋ (“lonely”), probably a reflexive of *yal- ("to take off") (compare giyin- (“to dress oneself”), reflexive of giy- (“to wear”)).
#
# []
# From Ottoman Turkish یاش‎ (yaş, “wet, moist, fresh”), from Proto-Turkic *yāĺ (“young, fresh”).
#
# []
# Passive form of yıkamak.
#
# []
# From Ottoman Turkish یول‎, from Proto-Turkic *yōl (“road”).  Compare Old Turkic [script needed] (yol).
#
# []
# yüksek ("high") + -lik ("-ness") (derivative suffix)
#
# []
# Borrowed from a Turkic language, compare Kazakh аға (ağa).
#
# []
# From Proto-Finno-Permic *ańće- like Komi-Permyak аддзыны (addzyny).
#
# []
# Borrowed from a Turkic language, compare Tatar апа (apa).
#
# []
# Borrowed from Chuvash эрне (erne).
#
# ['Chuvash']
# Of Permic origin, related to Komi-Permyak бан (ban).
#
# []
# From Proto-Permic [Term?], cognate to Komi-Permyak велавны (velavny).
#
# []
# A Permic word (*wäśä-) like Komi-Permyak висьны (visʹny), akin to Finnish väsyä.
#
# []
# From Proto-Finnic *waje.
#
# []
# From Proto-Permic *wanša, cognate to Komi-Permyak важ (važ). The Permic word is related to Estonian vana and  Finnish vanha.
#
# []
# A Permic word (*wäke-) like Komi-Permyak воны (vony).
#
# []
# From Proto-Finno-Ugric *wuďe. Cognates include Eastern Mari у (u), Finnish uusi and Hungarian új.
#
# []
# Related to Kazakh ору (orw).
#
# []
# From Proto-Uralic *künče.
#
# []
# A Permic word (*gud).
#
# []
# From Proto-Permic [Term?]. Cognates include Komi-Zyrian кар (kar).
#
# []
# From Proto-Uralic *käćetä, like Komi-Permyak кӧдзыд (ködzyd).
#
# []
# From a Permic *kud.
#
# []
# From Proto-Uralic *käle. Cognates include Komi-Permyak кыв (kyv), Finnish kieli and Northern Sami giella.
#
# []
# From Proto-Uralic *kule-.
#
# []
# From Proto-Uralic *lewle.
#
# []
# From Proto-Uralic *mene-.
#
# []
# From Proto-Permic *nu-, cognate to Komi-Permyak нуны (nuny).
#
# []
# From Proto-Permic [Term?], from Proto-Uralic *nejde.
#
# []
# From Proto-Permic *pośe, cognate to Komi-Permyak пӧсь (pösʹ).
#
# []
# From Proto-Uralic *puwe.
#
# []
# From Proto-Uralic *päŋe.
#
# []
# From Proto-Permic [Term?], cognate to Komi-Permyak пырны (pyrny).
#
# []
# From Proto-Permic [Term?], cognate to Komi-Permyak сьöкыд (sʹökyd).
#
# []
# From Proto-Permic [Term?], cognate to Komi-Permyak сетны (setny).
#
# []
# From Proto-Uralic *tumte-.
#
# []
# Related to Komi-Zyrian тӧлысь (tölysʹ) and Eastern Mari тылзе (tylze).
#
# []
# From Proto-Permic *turn, from Proto-Finno-Permic *tarna, borrowed from Indo-European, from Proto-Indo-European *tr̥nós. Cognate with Komi-Permyak турун (turun), Finnish taarna.
#
# []
# From Proto-Uralic *tule.
#
# []
# A Permic word like Komi-Permyak удж (udž).
#
# []
# From Proto-Uralic *elä-.
#
# []
# From Proto-Permic [Term?], cognate to Komi-Permyak чӧскыд (čöskyd).
#
# []
# From Proto-Permic [Term?], cognate to Komi-Permyak шуны (šuny).
#
# []
# From Proto-Slavic *brudъ.
#
# []
# From Proto-Slavic *grǫdь.
#
# []
# From Old Church Slavonic звьнѣти (zvĭněti), from Proto-Slavic *zvьněti. Ultimately from Proto-Indo-European *ǵʰwon-, *ǵʰwen-, *ǵʰaw-.
# Cognates with Polish dzwonić.
#
# []
# From Proto-Slavic *žiti, from Proto-Indo-European *gʷeih₃w- (“to live”). Cognate to Lithuanian gyventi, Sanskrit जीवति (jīvati), Latin vīvō.
#
# []
# From Old East Slavic жена (žena) +‎ -ка (-ka), cognate to Belarusian жо́нка (žónka).  Equivalent to жона́ (žoná) +‎ -ка (-ka). The root is from Proto-Slavic *žena, from Proto-Balto-Slavic *génāˀ, from Proto-Indo-European *gʷḗn.
#
# []
# From Old East Slavic коньць (konĭcĭ, “end; edge, border”), from Proto-Slavic *konьcь (“end”).
#
# []
# From Proto-Slavic *listъ (“leaf”).
#
# []
# From Proto-Slavic *ľubiti, from Proto-Indo-European *lewbʰ-.
#
# []
# From Proto-Slavic *mati, from Proto-Indo-European *méh₂tēr.
#
# []
# From Proto-Slavic *měsęcь, from Proto-Indo-European *mḗh₁n̥s.
#
# []
# From Proto-Slavic *nogъtь.
#
# []
# From Proto-Slavic *noga, from Proto-Indo-European *h₃nogʰ-.
#
# []
# From Proto-Slavic *edinъ, ultimately from Proto-Indo-European *óynos (“one, single”).
#
# []
# From Proto-Slavic *palica.
#
# []
# під- (pid-) +‎ -ня́ти (-njáty)
# []
# From Proto-Slavic *rogъ.
#
# []
# From Proto-Slavic *rǫka, from Proto-Balto-Slavic *ránkāˀ.
#
# []
# From Proto-Slavic *sila.
#
# []
# From Proto-Slavic *sъ̀nъ, from Proto-Indo-European *supnós.
#
# []
# From Proto-Slavic *starъ.
#
# []
# From Proto-Slavic *tъlstъ. Doublet of тлу́стий (tlústyj), a borrowing from Polish.
#
# []
# Inherited from Old East Slavic тънъкъ (tŭnŭkŭ), from Proto-Slavic *tьnъkъ.
#
# ['Old']
# From Old East Slavic хлѣбъ (xlěbŭ), from Proto-Slavic *xlěbъ, from Proto-Germanic *hlaibaz. Compare Gothic 𐌷𐌻𐌰𐌹𐍆𐍃 (hlaifs).
#
# []
# From Proto-Slavic *čekati (“to wait, await, expect”).
#
# []
# From Old East Slavic человѣкъ (čelověkŭ), from Proto-Slavic *čьlověkъ, *čelověkъ.
#
# []
# From Polish skóra, from Proto-Slavic *skora (“bast, skin”).
#
# []
# From Proto-Turkic *bāla.
#
# []
# From Proto-Turkic *burun.
#
# []
# From Proto-Turkic *ɨsɨg.
#
# []
# From Proto-Turkic *bań.
#
# []
# Cognate with Old Turkic [script needed] (al-).
#
# []
# From Chagatai آی‎ (ʾāy, “Moon; month”), from Proto-Turkic *āń(k) (“Moon; month”). Cognate with Uyghur ئاي‎ (ay, “moon; month”), Turkish ay (“moon; month”), Turkmen aý (“moon; month”), etc.
#
# []
# From Proto-Turkic *adak (“foot”).
#
# []
# From Proto-Turkic *kï̄ŕ (“girl, woman”). Cognate with Azerbaijani qız, Bashkir ҡыҙ (qïð), Crimean Tatar qız, Karakalpak qız, Kazakh қыз (qız), Kyrgyz кыз (kız), Old Turkic [script needed] (kïz), Ottoman Turkish قیز‎, Tatar кыз (qız), Turkish kız, Turkmen gyz, Tuvan кыс (kıs), Uyghur قىز‎ (qiz).
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From Proto-Turkic *dɨl.
#
# []
# From Proto-Turkic *dɨrŋa-k.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Related to Finnish soma.
#
# []
# Borrowed from Russian го́ре (góre).
#
# ['Russian']
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Probably related to Finnish hapata.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish katsoa.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish kalu.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish kääntää.
#
# []
# From katta +‎ -uz.
#
# []
# Related to Finnish koko.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From kuluda +‎ -nd.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish langeta.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish lauta, Estonian laud.
#
# []
# Borrowing from Russian лавка (lavka).
#
# ['Russian']
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish leikata.
#
# []
# Borrowed from Russian манить (manitʹ).
#
# ['Russian']
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# From mured +‎ -eta.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish näkyä.
#
# []
# Related to Finnish nousta.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Related to Finnish paeta.
#
# []
# Related to Finnish pakina.
#
# []
# Related to Finnish pakista and Karelian paišta.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish peittää.
#
# []
# Related to Finnish piirto.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish piirtää.
#
# []
# Related to Ingrian retu.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# Related to Finnish reuna.
#
# []
# Related to Finnish sanoa.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish sauvoa.
#
# []
# Related to Karelian sit.
#
# []
# Akin to Karelian täydyö.
#
# []
# From Proto-Finnic *teräbä.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish valita.
#
# []
# Related to Finnish varoa.
#
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# []
# (This etymology is missing or incomplete. Please add to it, or discuss it at the Etymology scriptorium.)
# Related to Finnish vyö.
#
# []
# From Proto-Uralic *waśke.
#
# []
# From Proto-Uralic *niŋä.
#
# []
# From Proto-Samoyedic *utå.
#
# []
# From Proto-Samoyedic *åjwå, from Proto-Uralic *ojwa.
#
# []
# From Proto-Uralic *pälä.
#
# []
# From Proto-Samoyedic *pä, from Proto-Uralic *puwe. Cognates include Hungarian fa and Finnish puu.
#
# []
# From Proto-Uralic *kajwa-.
#
# []
# From Proto-Uralic *kaŋe-.
#
# []
# From Proto-Samoyedic *koəjə.
#
# []
